# %%
import requests
import json
import matplotlib
import matplotlib.pyplot

# %%
mas=[]
for page in range(0,10):
    r=requests.get('https://api.hh.ru/vacancies?page=%s&per_page=100' % page)
    items = r.json()['items']
    for i in items:
        professions = {i['name']:i['salary']}
        mas.append(professions);
mas
# Out:
# [{'Менеджер по рекламе и маркетингу': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-консультант YOTA': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Электросварщик на автоматических и полуавтоматических машинах': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 19000,
#    'gross': False,
#    'to': 25000}},
#  {'Шлифовщик': {'currency': 'RUR', 'from': 35000, 'gross': True, 'to': 45000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Территориальный менеджер (салоны Билайн)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Медсестра': {'currency': 'RUR', 'from': 25000, 'gross': False, 'to': None}},
#  {'Специалист по работе с клиентами': None},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Менеджер по продажам септиков': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Системный администратор': None},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Юстировщик/конструктор оснастки по сборке оптических приборов': None},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Руководитель проектов (встроенные решения для автопроизводителей)/ Project Manager': None},
#  {'Инженер отдела организации и планирования ПИР': {'currency': 'RUR',
#    'from': 26000,
#    'gross': False,
#    'to': None}},
#  {'Водитель-курьер': {'currency': 'RUR',
#    'from': 12000,
#    'gross': False,
#    'to': 15000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Главный специалист по гидродинамическому моделированию': None},
#  {'Кадастровый инженер': None},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Менеджер проектов/ Project Manager': None},
#  {'Ведущий инженер': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Internal Communication and Company Culture Manager': None},
#  {'Training & Development Specialist/ Специалист по обучению и развитию': None},
#  {'Ведущий инженер отдела экологической и промышленной безопасности': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Инженер (1 категория)': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Инженер/инженер отдела инженерных изысканий (2 категория)': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Инженер': {'currency': 'RUR', 'from': 25000, 'gross': None, 'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Инженер отдела мониторинга технологических процессов': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 23000,
#    'gross': None,
#    'to': 23000}},
#  {'Кредитный специалист (м. Речной вокзал)': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': 28000}},
#  {'Кредитный специалист (м. Купчино)': {'currency': 'RUR',
#    'from': 23000,
#    'gross': None,
#    'to': 25000}},
#  {'Кредитный специалист (м. Садовая)': {'currency': 'RUR',
#    'from': 23000,
#    'gross': None,
#    'to': None}},
#  {'Специалист по кредитованию': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Администратор региона': {'currency': 'RUR',
#    'from': 19000,
#    'gross': False,
#    'to': 22000}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 28000}},
#  {'Кредитный специалист (ЧМЗ)': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Администратор региона': {'currency': 'RUR',
#    'from': 21000,
#    'gross': False,
#    'to': 23000}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Инженер 2 категории отдела мониторинга технологических процессов': None},
#  {'Ведущий инженер отдела геологии и подсчета запасов': {'currency': 'RUR',
#    'from': 35000,
#    'gross': None,
#    'to': None}},
#  {'Главный специалист отдела мониторинга технологических процессов': None},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Руководитель группы гидрогеологов отдела гидрогеологии': {'currency': 'RUR',
#    'from': 35000,
#    'gross': None,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'BYR',
#    'from': 500,
#    'gross': True,
#    'to': 650}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Главный специалист проектирования разработки': None},
#  {'Специалист отдела информационного обслуживания (ВТБ)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Руководитель группы гидрогеологов (Отдел гидродинамического моделирования)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по работе с клиентами': {'currency': 'BYR',
#    'from': 400,
#    'gross': False,
#    'to': 1000}},
#  {'Специалист контакт-центра (Банк ВТБ)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Ведущий инженер отдела мониторинга разработки': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Администратор ветеринарной клиники': None},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Главный менеджер по развитию ипотечного кредитования': {'currency': 'RUR',
#    'from': 30700,
#    'gross': True,
#    'to': None}},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Повар': {'currency': 'RUR', 'from': 20000, 'gross': False, 'to': 25000}},
#  {'Маркетолог': None},
#  {'Менеджер по продажам и обслуживанию / Продавец-консультант в салон "Ростелеком" (м. Чкаловская)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 50000}},
#  {'Начальник службы эксплуатации': None},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Сварщик, помощник сварщика': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 35000}},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Менеджер по туризму': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': 40000}},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Менеджер по персоналу': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Креативный дизайнер': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 120000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Юрист': None},
#  {'Специалист по таргетированной рекламе': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Ведущий специалист по контекстной рекламе': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Ассистент аккаунт-менеджера': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 35000}},
#  {'Специалист по контекстной рекламе': None},
#  {'Account Manager/Аккаунт Менеджер': {'currency': 'RUR',
#    'from': 130000,
#    'gross': True,
#    'to': 150000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 12000,
#    'gross': True,
#    'to': 40000}},
#  {'Менеджер по продажам лизинга': None},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Администратор салона красоты': {'currency': 'BYR',
#    'from': 200,
#    'gross': True,
#    'to': None}},
#  {'Программист Python': None},
#  {'Арматурщик (Российская Федерация)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Специалист по продажам': {'currency': 'BYR',
#    'from': 350,
#    'gross': True,
#    'to': 800}},
#  {'Плотник-бетонщик (в РФ)': {'currency': 'USD',
#    'from': 1000,
#    'gross': False,
#    'to': 1330}},
#  {'Водитель на авто компании, Киев': {'currency': 'UAH',
#    'from': 10000,
#    'gross': False,
#    'to': 18000}},
#  {'Автомеханик': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 60000}},
#  {'Водитель дорожной техники (категории С, D, Е) на машину КАМАЗ/КАМАЗ с прицепом в РФ': {'currency': 'RUR',
#    'from': 48000,
#    'gross': True,
#    'to': 80000}},
#  {'Водитель дорожной техники с кат.В для работы в РФ': {'currency': 'RUR',
#    'from': 48000,
#    'gross': False,
#    'to': 80000}},
#  {'Каменщик (в РФ)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Сетевой инженер/ Есипово': None},
#  {'Облицовщик-плиточник (в РФ)': {'currency': 'USD',
#    'from': 1000,
#    'gross': False,
#    'to': 2000}},
#  {'Монтажник сантехсистем и оборудования (сантехник) в РФ': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Assistant to CFO (Esipovo)': None},
#  {'Инженер цеха сборки (Производство, Есипово)': None},
#  {'Гипсокартонщик / Плотник-отделочник в РФ': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 80000}},
#  {'Инженер по анализу геометрии кузова (Производство, Есипово)': None},
#  {'Слесарь-сантехник': None},
#  {'Закройщица/закройщик на самозакрой': None},
#  {'Специалист по безопасности (Производство, Есипово)': None},
#  {'Менеджер оптового отдела продаж': {'currency': 'RUR',
#    'from': 45000,
#    'gross': True,
#    'to': 70000}},
#  {'Инженер по системам менеджмента (Производство, Есипово)': None},
#  {'Врач-онколог- маммолог': None},
#  {'Инженер по анализу процесса окраски (Производство, Есипово)': None},
#  {'Специалист по работе с недвижимостью': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Начальник цеха сборки (Производство, Есипово)': None},
#  {'Начальник строительного участка': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 80000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Маркетолог': None},
#  {'Врач-стоматолог': None},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Маркетолог': None},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант в магазин нижнего белья': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 30000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 40000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Производитель работ ( монолитные работы)': {'currency': 'RUR',
#    'from': 65000,
#    'gross': False,
#    'to': 65000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Руководитель проекта/ Менеджер по развитию бизнеса': None},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Разнорабочий в столярную мастерскую': {'currency': 'BYR',
#    'from': 400,
#    'gross': False,
#    'to': 400}},
#  {'Мастер по сварке': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': 110000}},
#  {'Риэлтор на входящие заявки': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 75000}},
#  {'Менеджер по персоналу': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Парикмахер-универсал': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Парикмахер': None},
#  {'Специалист лазерной эпиляции': {'currency': 'RUR',
#    'from': 24000,
#    'gross': False,
#    'to': None}},
#  {'Швея-портной в магазин ткани': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-кассир (ТК "Авеню") м. Проспект Просвещения': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Менеджер по товару / Кладовщик (ТЦ "Сити")': {'currency': 'RUR',
#    'from': 26000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по товару / Кладовщик': {'currency': 'RUR',
#    'from': 27000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТК "Континент Бухарестская")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Методолог Корпоративные Кредиты': {'currency': 'RUR',
#    'from': 200000,
#    'gross': False,
#    'to': 250000}},
#  {'Менеджер по товару в ТК "Ярмарка"': {'currency': 'RUR',
#    'from': None,
#    'gross': True,
#    'to': 26000}},
#  {'Менеджер по товару (в ТК "Охта Молл")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по товару в ТК Меркурий': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Заместитель директора магазина (Спб)': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по товару в ТЦ "Cubus", Гатчина': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТК "Фиолент")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-флорист': {'currency': 'RUR',
#    'from': 7500,
#    'gross': False,
#    'to': 12000}},
#  {'Продавец-кассир товаров для детей (в ТК "Мега Дыбенко")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТРК "Мега ПАРНАС")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Главный бухгалтер': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 50000}},
#  {'Маркетолог': None},
#  {'Продавец-кассир (ТРК "Французский бульвар")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Акваполис")': {'currency': 'RUR',
#    'from': 22000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Апельсин")': {'currency': 'RUR',
#    'from': 24000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Европолис")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Карусель" Савушкина 116)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Лондон Молл")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Макси")': {'currency': 'RUR',
#    'from': 26000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "РИО")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Сити молл")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Электромонтажник': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 70000}},
#  {'Продавец-кассир (ТЦ "Титан Арена")': {'currency': 'RUR',
#    'from': 27000,
#    'gross': True,
#    'to': None}},
#  {'Специалист отдела снабжения': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 120000}},
#  {'Продавец-кассир (ТЦ "Южный")': {'currency': 'RUR',
#    'from': 27000,
#    'gross': True,
#    'to': None}},
#  {'Продавец (ТК "Балкания Nova")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец товаров для детей': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Бухгалтер': {'currency': 'RUR',
#    'from': 43000,
#    'gross': False,
#    'to': 52000}},
#  {'Заместитель руководителя по работе с регионами': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 35000}},
#  {'Начальник планово-экономического отдела': None},
#  {'Менеджер по работе с ключевыми клиентами': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 150000}},
#  {'Бровист': {'currency': 'RUR', 'from': 50000, 'gross': False, 'to': None}},
#  {'Няня': {'currency': 'UAH', 'from': 16000, 'gross': False, 'to': 26000}},
#  {'Менеджер по бронированию авиа и железнодорожных билетов': None},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 17000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 17000,
#    'gross': False,
#    'to': None}},
#  {'Мерчендайзер': None},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист (м. Старая Деревня)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Региональный менеджер по продажам': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 50000}},
#  {'Кредитный специалист (м. Проспект Просвещения)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Консультант (помощник) нотариуса': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 50000}},
#  {'Кредитный специалист (м.Проспект Большевиков)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Quality Assurance Engineer': {'currency': 'USD',
#    'from': 800,
#    'gross': True,
#    'to': 1300}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 14000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 45000,
#    'gross': True,
#    'to': None}},
#  {'Специалист линии поддержки англоговорящих клиентов': {'currency': 'RUR',
#    'from': 24000,
#    'gross': True,
#    'to': 40000}},
#  {'Агент по продажам жилой недвижимости': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Специалист отдела по расследованию мошеннических и спорных операций': {'currency': 'RUR',
#    'from': 27000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 150000}},
#  {'Специалист по работе с клиентами в отделение': None},
#  {'Су-шеф': {'currency': 'RUR', 'from': 60000, 'gross': False, 'to': 60000}},
#  {'Продавец консультант': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 40000}},
#  {'Менеджер по продажам строительных материалов': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Сварщик НАКС': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Оформитель документов': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': None}},
#  {'Сервис-консультант СК Режим (проспект Героев, проспект Молодежный, ул. Щербакова)': {'currency': 'RUR',
#    'from': 36000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-консультант / менеджер по продажам строительных материалов': None},
#  {'Менеджер отдела продаж': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 80000}},
#  {'Ведущий инженер по слаботочным системам и автоматике': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 150000}},
#  {'Мастер ногтевого сервиса': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 40000}},
#  {'Бармен-официант': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 40000}},
#  {'Фармацевт-провизор': {'currency': 'RUR',
#    'from': 18000,
#    'gross': False,
#    'to': 22000}},
#  {'Технический специалист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 50000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Мастер ногтевого сервиса': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 120000}},
#  {'Менеджер по оптовым продажам': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': None}},
#  {'Машинист катка дорожного/асфальтового': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 70000}},
#  {'Официант-бармен': {'currency': 'BYR',
#    'from': 450,
#    'gross': True,
#    'to': None}},
#  {'Водитель': {'currency': 'RUR', 'from': 30000, 'gross': False, 'to': 40000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Ведущий PHP/JS разработчик': {'currency': 'RUR',
#    'from': 110000,
#    'gross': False,
#    'to': 150000}},
#  {'Помощник руководителя': {'currency': 'RUR',
#    'from': 43000,
#    'gross': True,
#    'to': 47000}},
#  {'Middle Front-end developer/верстальщик': {'currency': 'USD',
#    'from': 1200,
#    'gross': True,
#    'to': 1800}},
#  {'Управляющий бутиком': None},
#  {'Начальник ПОД/ФТ': None},
#  {'Руководитель отдела продаж отопительного оборудования': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант/кассир-продавец': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': None}},
#  {'Директор по производству': None},
#  {'Бухгалтер': {'currency': 'RUR', 'from': 45000, 'gross': False, 'to': None}},
#  {'Менеджер ресторана': {'currency': 'RUR',
#    'from': 55000,
#    'gross': False,
#    'to': None}},
#  {'Водитель такси на личном автомобиле': {'currency': 'BYR',
#    'from': 1000,
#    'gross': True,
#    'to': 2000}},
#  {'Водитель-экспедитор с личным грузовым автомобилем от 1,5 до 2 тонн': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 50000}},
#  {'Водитель-экспедитор с личным грузовым автомобилем от 1,5 до 2 тонн': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 60000}},
#  {'Продавец-консультант': None},
#  {'Грузчик': {'currency': 'RUR', 'from': 20000, 'gross': False, 'to': 27000}},
#  {'Менеджер отдела продаж': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': 90000}},
#  {'Водитель-экспедитор с личным грузовым автомобилем (от 1,5 до 2 тонн, будка)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 48000}},
#  {'Бухгалтер': {'currency': 'RUR', 'from': 23000, 'gross': False, 'to': None}},
#  {'Senior Java Developer': None},
#  {'Повар универсал': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 50000}},
#  {'Менеджер по продажам HoReCa и работе с производствами': None},
#  {'Senior PHP Developer / Architect': None},
#  {'Медицинская сестра': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Секретарь-делопроизводитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 35000}},
#  {'PHP Developer': None},
#  {'Senior .Net developer': None},
#  {'Веб-дизайнер': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Python разработчик': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': 110000}},
#  {'Помощник коммерческого директора': {'currency': 'RUR',
#    'from': 19000,
#    'gross': True,
#    'to': 35000}},
#  {'Руководитель отдела разработки': None},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 35000}},
#  {'Специалист по налогообложению': None},
#  {'Тестировщик мобильных приложений': None},
#  {'Специалист по обработке первичной документации': None},
#  {'Ведущий бухгалтер по учёту заработной платы': None},
#  {'Аналитик (бухгалтерия, зарплата и кадры)': None},
#  {'Специалист по обработке финансовых запросов': None},
#  {'Специалист по кадровому администрированию': None},
#  {'Старший специалист/Ведущий специалист отдела продаж ипотечных продуктов': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Специалист(Старший/Главный) отдела продаж ипотечных кредитов': None},
#  {'Специалист отдела продаж ипотечных кредитов (старший/главный)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 55000}},
#  {'SMM-менеджер(банк)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': 100000}},
#  {'Ведущий специалист Информационного центра': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 45000}},
#  {'Кассир-операционист': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 32000}},
#  {'Старший/ведущий специалист отдела продаж ипотечных продуктов': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': None}},
#  {'Старший/ведущий специалист отдела продаж ипотечных продуктов': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': None}},
#  {'Старший юрисконсульт Отдела судебного взыскания (направление – судебное взыскание)': {'currency': 'RUR',
#    'from': 65000,
#    'gross': True,
#    'to': 72000}},
#  {'Юрисконсульт Отдела правового сопровождения кредитования и розничного бизнеса': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': 70000}},
#  {'Директор по развитию ипотечного кредитования': {'currency': 'RUR',
#    'from': 150000,
#    'gross': True,
#    'to': 180000}},
#  {'Руководитель отдела по работе с партнерами': {'currency': 'RUR',
#    'from': 55000,
#    'gross': True,
#    'to': 90000}},
#  {'Старший специалист группы Процессинга': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Кассир-операционист': {'currency': 'RUR',
#    'from': 23000,
#    'gross': True,
#    'to': 23000}},
#  {'Главный/ведущий специалист/заместитель Руководителя Управление внутреннего аудита': {'currency': 'RUR',
#    'from': 87000,
#    'gross': True,
#    'to': 87000}},
#  {'Инженер-сметчик': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по продажам': {'currency': 'UZS',
#    'from': 1000000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 60000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 25000}},
#  {'SMM-маркетинг менеджер': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Инженер по интеграции (встроенные решения для автопроизводителей)': None},
#  {'Менеджер проектов': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Бармен/Бариста': {'currency': 'BYR',
#    'from': 400,
#    'gross': True,
#    'to': None}},
#  {'Сотрудник Росгвардии': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 60000}},
#  {'Повар': {'currency': 'BYR', 'from': 500, 'gross': True, 'to': None}},
#  {'Прораб на монолит': None},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер отдела закупок': {'currency': 'RUR',
#    'from': 65000,
#    'gross': False,
#    'to': 85000}},
#  {'Разработчик React Native': {'currency': 'RUR',
#    'from': 150000,
#    'gross': False,
#    'to': None}},
#  {'Бармен,официант,повар,администратор,кальянщик,кухонный рабочий': {'currency': 'BYR',
#    'from': 300,
#    'gross': True,
#    'to': 500}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Менеджер по продажам (государственные закупки)': None},
#  {'Водитель в отель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Автослесарь': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по работе с дистрибьюторами и аптечными сетями': {'currency': 'RUR',
#    'from': 220000,
#    'gross': True,
#    'to': None}},
#  {'Frontend-разработчик / HTML-верстальщик': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Директор типографии': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 100000}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 8000,
#    'gross': True,
#    'to': 20000}},
#  {'Performance Tester': None},
#  {'Оценщик': None},
#  {'Кассир (г. Красноармейск)': {'currency': 'RUR',
#    'from': 24000,
#    'gross': False,
#    'to': 43000}},
#  {'Менеджер по работе с клиентами (образование за рубежом)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Backend разработчик': None},
#  {'Педагог классического танца\\Педагог развития данных': None},
#  {'Администратор салона красоты': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 20000}},
#  {'Кассир, г. Егорьевск': {'currency': 'RUR',
#    'from': 22000,
#    'gross': False,
#    'to': 43000}},
#  {'Педагог классического танца\\Педагог развития данных': {'currency': 'RUR',
#    'from': 1000,
#    'gross': False,
#    'to': 1500}},
#  {'Бармен': {'currency': 'RUR', 'from': 40000, 'gross': False, 'to': None}},
#  {'Помощник менеджера по продажам': {'currency': 'BYR',
#    'from': 400,
#    'gross': False,
#    'to': 600}},
#  {'Парикмахер': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 100000}},
#  {'Менеджер по продажам услуг': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 70000}},
#  {'Руководитель отдела продаж': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 200000}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Личный помощник руководителя / Персональный ассистент': {'currency': 'RUR',
#    'from': None,
#    'gross': True,
#    'to': 287649}},
#  {'Помощник менеджера по продажам': {'currency': 'RUR',
#    'from': 10000,
#    'gross': False,
#    'to': 25000}},
#  {'Бухгалтер': {'currency': 'RUR', 'from': 25000, 'gross': True, 'to': None}},
#  {'Водитель Uber на авто компании': {'currency': 'BYR',
#    'from': 750,
#    'gross': False,
#    'to': 1300}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Бариста': {'currency': 'BYR', 'from': 550, 'gross': False, 'to': 700}},
#  {'Ведущий разработчик Java': {'currency': 'RUR',
#    'from': 120000,
#    'gross': True,
#    'to': 220000}},
#  {'Экспедитор (Водитель)': {'currency': 'BYR',
#    'from': 700,
#    'gross': False,
#    'to': 700}},
#  {'Кредитный консультант': {'currency': 'RUR',
#    'from': 28000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по кредитованию': {'currency': 'RUR',
#    'from': 36000,
#    'gross': True,
#    'to': 60000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': None}},
#  {'HTML-верстальщик': {'currency': 'RUR',
#    'from': 90000,
#    'gross': True,
#    'to': None}},
#  {'Водитель МАЗ бункеровоз': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер торгового зала / Спорт-лидер (спортивные товары, м. Фили)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': 100000}},
#  {'Менеджер торгового зала / Спорт-лидер (спортивные товары, м. Пражская)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': 100000}},
#  {'Дизайнер-консультант / Менеджер по продажам без опыта (кухонная мебель, ТЦ Красный Кит)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Дизайнер-консультант / Менеджер по продажам без опыта (кухонная мебель, ТЦ Красный Кит)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Дизайнер-консультант/Менеджер по продажам (кухонная мебель, ТЦ Красный Кит)': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер торгового сектора/Спорт-лидер (спортивные товары, м. Юго-Западная)': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 100000}},
#  {'Контент менеджер (Маркетинг) / Специалист по рекламе': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Мастер отделочных работ / Отделочник': {'currency': 'RUR',
#    'from': 25,
#    'gross': False,
#    'to': 40}},
#  {'Начальника отдела кадров': {'currency': 'KZT',
#    'from': 150000,
#    'gross': True,
#    'to': None}},
#  {'Парикмахер-универсал': {'currency': 'RUR',
#    'from': 85000,
#    'gross': False,
#    'to': 160000}},
#  {'Шеф-повар': None},
#  {'Официант': {'currency': 'RUR', 'from': 40000, 'gross': None, 'to': None}},
#  {'Бухгалтер по расчетам с поставщиками': None},
#  {'Менеджер по продажам профессиональной косметики для волос': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 150000}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Продавец-консультант электрики': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': None}},
#  {'Помощник руководителя отдела по подбору персонала': {'currency': 'RUR',
#    'from': None,
#    'gross': True,
#    'to': 65000}},
#  {'Водитель КаМаз ФАУН мусоровоз': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': None}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Web-дизайнер': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': 70000}},
#  {'Junior Email-маркетолог': None},
#  {'Водитель-экспедитор категории «Е»': None},
#  {'Менеджер по оптовым продажам инженерной сантехники': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 140000}},
#  {'Водитель-экспедитор категории «Е»': None},
#  {'Няня': {'currency': 'RUR', 'from': 60000, 'gross': False, 'to': 70000}},
#  {'Начальник автоколонны (г. Чита)': None},
#  {'Тренер-технолог/Технолог-колорист': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Руководитель проекта (дорожное строительство)': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 55000}},
#  {'Юрист': {'currency': 'RUR', 'from': 70000, 'gross': False, 'to': 90000}},
#  {'Гейм-дизайнер': None},
#  {'Менеджер по продаже услуг': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Начинающий специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Начинающий специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам сервиса онлайн-записи': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 100000}},
#  {'Junior Documentation Manager': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': 20000}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Export Documentation Manager': {'currency': 'RUR',
#    'from': 18000,
#    'gross': True,
#    'to': 30000}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Врач лаборант в лабораторию сети ветеринарных центров': None},
#  {'Маляр по дереву': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 45000}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Помощник бухгалтера по документам': {'currency': 'RUR',
#    'from': 12000,
#    'gross': False,
#    'to': 15000}},
#  {'Полицейский водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Региональный представитель портала недвижимости': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 70000}},
#  {'Региональный представитель портала недвижимости': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 60000}},
#  {'Оператор call-центра': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант детского магазина': {'currency': 'KZT',
#    'from': 50000,
#    'gross': True,
#    'to': 100000}},
#  {'Администратор стоматологической клиники': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам и обслуживанию / Продавец-консультант в салон "Ростелеком" (м. Адмиралтейская)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 50000}},
#  {'Территориальный торговый представитель (Ярославль, Кострома и области)': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Инженер ПТО по сварочно-монтажным работам': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Водитель-экспедитор': {'currency': 'BYR',
#    'from': 1200,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 200000}},
#  {'Врач-рентгенолог МРТ и КТ': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 100000}},
#  {'Помощник юриста': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 30000}},
#  {'Automation QA Engineer (CSO TD OP)': None},
#  {'Специалист по продажам': {'currency': 'BYR',
#    'from': 800,
#    'gross': True,
#    'to': None}},
#  {'UFT Automation Engineer': None},
#  {'Менеджер по продвижению нефтепромысловых реагентов, оборудования для добычи нефти и газа': None},
#  {'Solution PM': None},
#  {'Program Manager': None},
#  {'Администратор фитнес студии': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Специалист технической поддержки': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 28000}},
#  {'Менеджер по продажам оптового отдела': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 100000}},
#  {'Повар холодного цеха': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 40000}},
#  {'Продавец-кассир': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 45000}},
#  {'Преподаватель испанского/английского языков': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 75000}},
#  {'Руководитель отдела договоров и комплектаций': None},
#  {'Трафик-менеджер / Интернет-маркетолог': None},
#  {'Администратор отеля': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 40000}},
#  {'Автоэлектрик': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Водитель категории D и C': None},
#  {'Столяр-станочник / Столяр-мебельщик': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Начальник отдела/управления/департамента финансового учета и отчетности страховой компании': None},
#  {'Старший рекрутер, hr-специалист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 80000}},
#  {'Преподаватель английского языка': None},
#  {'Дизайнер-консультант по шторам, обоям': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': None}},
#  {'Офис-менеджер/менеджер': {'currency': 'UAH',
#    'from': None,
#    'gross': False,
#    'to': 8000}},
#  {'Товаровед-оценщик в ломбард': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 60000}},
#  {'Менеджер по продажам в отель': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 50000}},
#  {'Помощник мастера, оператор чесального оборудования': {'currency': 'BYR',
#    'from': 800,
#    'gross': True,
#    'to': None}},
#  {'Переводчик фрилансер немецкого языка': None},
#  {'Специалист планово-экономического отдела': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Бармен-кассир': {'currency': 'RUR',
#    'from': 38000,
#    'gross': True,
#    'to': None}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': False,
#    'to': None}},
#  {'Пекарь-кондитер': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 35000}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': False,
#    'to': None}},
#  {'Менеджер / Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 39000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по администрированию и ведению проектов': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 60000}},
#  {'Электромонтажник': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 60000}},
#  {'Специалист по администрированию и ведению проектов': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 60000}},
#  {'Менеджер по работе с корпоративными клиентами': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 75000}},
#  {'Повар на завтраки': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 37000}},
#  {'Специалист по администрированию и ведению проектов': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 60000}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': True,
#    'to': None}},
#  {'Монтажник оборудования связи': {'currency': 'BYR',
#    'from': 400,
#    'gross': False,
#    'to': None}},
#  {'Консультант 1С/Аналитик 1с': {'currency': 'RUR',
#    'from': 120000,
#    'gross': False,
#    'to': 155000}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': False,
#    'to': None}},
#  {'Директор по продажам IT проектов.': {'currency': 'RUR',
#    'from': 150000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по продажам услуг': {'currency': 'UAH',
#    'from': 5000,
#    'gross': True,
#    'to': 15000}},
#  {'Менеджер по продажам услуг': {'currency': 'UAH',
#    'from': 5000,
#    'gross': True,
#    'to': 15000}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': False,
#    'to': None}},
#  {'Торговый представитель': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 150000}},
#  {'Инженер ПТО (дорожное строительство)': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Маркетолог': None},
#  {'Клубный промоутер': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 80000}},
#  {'Брокер по коммерческой недвижимости': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 200000}},
#  {'Переводчик фрилансер французского языка': None},
#  {'Мерчендайзер': {'currency': 'UAH',
#    'from': 5000,
#    'gross': False,
#    'to': None}},
#  {'Официант': {'currency': 'RUR', 'from': 35000, 'gross': False, 'to': 40000}},
#  {'Руководитель проектов (разработка ПО)': None},
#  {'Вечерний секретарь': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 50000}},
#  {'Инженер ПТО': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 60000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'KZT',
#    'from': 150000,
#    'gross': False,
#    'to': 300000}},
#  {'Повар-кондитер': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 40000}},
#  {'Ведущий инженер по качеству (Senior Manual QA Engineer)': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': 130000}},
#  {'Менеджер по продажам': None},
#  {'Специалист по охране труда': None},
#  {'Промоутер-распространитель': {'currency': 'RUR',
#    'from': 11000,
#    'gross': False,
#    'to': 20000}},
#  {'Финансист-экономист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 40000}},
#  {'Переводчик фрилансер арабского языка': None},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Frontend-разработчик (верстальщик)': None},
#  {'Администратор СПА-салона': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 60000}},
#  {'Дизайнер интерфейсов (Web-дизайнер)': None},
#  {'Су-шеф (повар-универсал)': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Коренщица/коренщик': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 36000}},
#  {'Менеджер лаборатории / офис-менеджер': None},
#  {'Менеджер по маркетингу и PR': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'С# - разработчик': {'currency': 'RUR',
#    'from': 100000,
#    'gross': True,
#    'to': 150000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 50000}},
# ...
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Category manager ( Директор по закупкам/ Коммерческий директор) - relocation': None},
#  {'Водитель на автомобиль компании Hyundai Solaris Nissan Almera': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 150000}},
#  {'Региональный менеджер по работе с ключевыми клиентами': {'currency': 'RUR',
#    'from': 45000,
#    'gross': True,
#    'to': 120000}},
#  {'Менеджер по работе с ключевыми клиентами': {'currency': 'RUR',
#    'from': 45000,
#    'gross': True,
#    'to': 120000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 50000}},
#  {'Пекарь': {'currency': 'BYR', 'from': 700, 'gross': True, 'to': None}},
#  {'Программист iOS': None},
#  {'Бариста/кассир': {'currency': 'RUR',
#    'from': 28000,
#    'gross': False,
#    'to': 38000}},
#  {'Преподаватель по экономике на английском языке': None},
#  {'Программист 1С': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Кладовщик-комплектовщик (м. Электросила, м. Бухарестская)': None},
#  {'Менеджер по продажам - консультант/секретарь': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 200000}},
#  {'Секретарь-делопроизводитель': {'currency': 'RUR',
#    'from': 75000,
#    'gross': False,
#    'to': 85000}},
#  {'IT and Digital Programs Coordinator': {'currency': 'RUR',
#    'from': 78000,
#    'gross': True,
#    'to': None}},
#  {'Водитель на автомобиль компании': None},
#  {'Старший продакт-менеджер по категории "Крепкие спиртные напитки"': None},
#  {'Тендер-менеджер': None},
#  {'Мерчендайзер-консультант на электроинструмент мирового бренда': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 21693}},
#  {'Специалист направления мотивации и оплаты труда/C&B': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Архитектор-концептуалист': None},
#  {'Промоутер-консультант (бытовая техника Midea)': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 65000}},
#  {'Инженер по программно-аппаратному обеспечению технологии интернета вещей': None},
#  {'Медиа-байер / специалист по закупке трафика': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 70000}},
#  {'Продавец-консультант (техника GARDENA)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по работе с розничными точками продаж (Luxottica)': None},
#  {'Продавец-консультант (Gardena)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Разработчик C++': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир магазина обуви': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 40000}},
#  {'Помощник руководителя/менеджер': {'currency': 'UAH',
#    'from': 10000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер IT-проектов': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 120000}},
#  {'Продавец-консультант в ТЦ': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': 35000}},
#  {'Менеджер по работе со студентами': {'currency': 'RUR',
#    'from': 44000,
#    'gross': True,
#    'to': 48000}},
#  {'Маркетолог (блогер)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': None}},
#  {'Техник-универсал': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Разработчик C++': {'currency': 'RUR',
#    'from': 90000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по корпоративным продажам': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 80000}},
#  {'Менеджер по работе с корпоративными клиентами': {'currency': 'RUR',
#    'from': 52000,
#    'gross': True,
#    'to': 70000}},
#  {'Торговый представитель': {'currency': 'RUR',
#    'from': 24000,
#    'gross': True,
#    'to': 40000}},
#  {'Монтажник': {'currency': 'RUR', 'from': 25000, 'gross': True, 'to': 55000}},
#  {'Руководитель отдела аренды': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': None}},
#  {'Оператор печатного оборудования': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': 25000}},
#  {'Секретарь на ресепшен': {'currency': 'RUR',
#    'from': 22000,
#    'gross': None,
#    'to': 26000}},
#  {'Дизайнер': {'currency': 'RUR', 'from': 25000, 'gross': False, 'to': 35000}},
#  {'Менеджер по работе с клиентами (в сервисный центр)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 23000}},
#  {'Менеджер по работе с клиентами (производственное направление)': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': 105000}},
#  {'Заместитель Руководителя Макрорегиона Юг по продажам': None},
#  {'Руководитель отдела продаж': None},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Инженер-конструктор': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 45000}},
#  {'Разработчик C++': {'currency': 'RUR',
#    'from': 100000,
#    'gross': True,
#    'to': None}},
#  {'Помощник установщика': {'currency': 'RUR',
#    'from': 30000,
#    'gross': None,
#    'to': 45000}},
#  {'Product Designer/Дизайнер продукта': {'currency': 'RUR',
#    'from': 80000,
#    'gross': True,
#    'to': None}},
#  {'Product Designer/Дизайнер продукта': {'currency': 'RUR',
#    'from': 80000,
#    'gross': True,
#    'to': None}},
#  {'Product Designer/Дизайнер продукта': {'currency': 'RUR',
#    'from': 80000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по продажам в интернет-магазин (секс шоп)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 50000}},
#  {'Водитель такси': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 150000}},
#  {'Разработчик C++': {'currency': 'RUR',
#    'from': 115000,
#    'gross': True,
#    'to': None}},
#  {'Административный помощник': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Ведущий менеджер по туризму CORAL TRAVEL': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 200000}},
#  {'Педагог раннего развития/Монтессори-педагог/Детский педагог-психолог': None},
#  {'Врач-гинеколог': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 170000}},
#  {'Секретарь': None},
#  {'Администратор-кассир стоматологической клиники': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 45000}},
#  {'Заместитель главного бухгалтера': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Старший бухгалтер (взаиморасчеты с зарубежными поставщиками)': {'currency': 'RUR',
#    'from': 65000,
#    'gross': False,
#    'to': None}},
#  {'SMM-менеджер': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': None}},
#  {'Главный инженер проекта (ГИП)': None},
#  {'Менеджер по продажам новостроек': {'currency': 'RUR',
#    'from': 85000,
#    'gross': True,
#    'to': 300000}},
#  {'Фотограф': {'currency': 'RUR', 'from': 30000, 'gross': False, 'to': None}},
#  {'Фармацевт-провизор': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 35000}},
#  {'Ветеринарный врач': {'currency': 'RUR',
#    'from': 10000,
#    'gross': True,
#    'to': 22000}},
#  {'Менеджер отдела продаж по работе с ключевыми клиентами': {'currency': 'KZT',
#    'from': 200000,
#    'gross': False,
#    'to': 1000000}},
#  {'Охранник': {'currency': 'RUR', 'from': 40000, 'gross': False, 'to': None}},
#  {'Менеджер отдела продаж': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 200000}},
#  {'Охранник': {'currency': 'RUR', 'from': None, 'gross': True, 'to': 45000}},
#  {'Вечерний специалист по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер отдела продаж': {'currency': 'RUR',
#    'from': None,
#    'gross': True,
#    'to': 120000}},
#  {'Менеджер переводчик бюро переводов': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 40000}},
#  {'Управляющий Converse': {'currency': 'RUR',
#    'from': 55000,
#    'gross': True,
#    'to': 75000}},
#  {'Вечерний менеджер': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Закройщик': {'currency': 'BYR', 'from': 600, 'gross': False, 'to': None}},
#  {'Водитель-экспедитор': {'currency': 'RUR',
#    'from': 52000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер в отдел телефонных продаж': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Комлектовщик  (Крекшино/Бекасово)': {'currency': 'RUR',
#    'from': 52000,
#    'gross': True,
#    'to': None}},
#  {'Full-stack разработчик (PHP)': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Торговый представитель': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 55000}},
#  {'Дизайнер-иллюстратор': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 50000}},
#  {'Менеджер визового отдела': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Full-Stack разработчик': None},
#  {'Младший менеджер по работе с клиентами': None},
#  {'Ведущий инженер отдела технической поддержки': None},
#  {'Тестировщик': None},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 50000}},
#  {'Frontend-разработчик': None},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 120000}},
#  {'Менеджер группы продаж': None},
#  {'Сварщик рекламных конструкций': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 50000}},
#  {'Главный специалист группы ипотечного кредитования': None},
#  {'Водитель-экспедитор': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 45000}},
#  {'Консультант': None},
#  {'Менеджер по туризму': {'currency': 'RUR',
#    'from': 65000,
#    'gross': False,
#    'to': 165000}},
#  {'Заместитель начальника отдела бухгалтерского учета в аудиторскую фирму': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Администратор': {'currency': 'RUR',
#    'from': 12000,
#    'gross': False,
#    'to': 15000}},
#  {'SMM-менеджер/Контент-менеджер': None},
#  {'Специалист по прямым продажам': None},
#  {'Повар на хачапури': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по прямым продажам': None},
#  {'Специалист по прямым продажам': None},
#  {'Секретарь': {'currency': 'RUR', 'from': 25000, 'gross': True, 'to': None}},
#  {'Водитель-инкассатор': None},
#  {'Клиентский менеджер': None},
#  {'Менеджер по обслуживанию': None},
#  {'Продавец-кассир': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 35000}},
#  {'Сборщик мебели': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Промоутер': {'currency': 'RUR', 'from': 10000, 'gross': False, 'to': None}},
#  {'Прораб (ОВ / ВК)': None},
#  {'Медицинский представитель': {'currency': 'RUR',
#    'from': 48000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по туризму': {'currency': 'BYR',
#    'from': 700,
#    'gross': False,
#    'to': 3000}},
#  {'Менеджер по продажам (спорт/фитнес клуб)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 70000}},
#  {'Оператор фасовочной линии': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер': None},
#  {'Помощник воспитателя в частный детский сад': {'currency': 'RUR',
#    'from': 19000,
#    'gross': False,
#    'to': None}},
#  {'Qa engineer': None},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 23000,
#    'gross': False,
#    'to': 36000}},
#  {'Комплектовщик': {'currency': 'RUR',
#    'from': 22000,
#    'gross': False,
#    'to': None}},
#  {'Администратор в Салон Красоты': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 35000}},
#  {'Водитель погрузчика': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Водитель погрузчика': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Руководитель отдела продаж': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 120000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер торгового отдела': None},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 80000}},
#  {'Менеджер кафе': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Официант': {'currency': 'RUR', 'from': 20000, 'gross': False, 'to': None}},
#  {'Менеджер по продажам Департамента ипотечного кредитования': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 70000}},
#  {'Специалист по бронированию': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Коммерческий директор проекта- 2ГИС-Саранск': None},
#  {'Слесарь аварийно-восстановительных работ': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': None}},
#  {'PHP Developer': {'currency': 'USD',
#    'from': 1200,
#    'gross': False,
#    'to': 1800}},
#  {'Chief Engineer / Главный инженер': None},
#  {'Врач косметолог (дерматокосметолог)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 120000}},
#  {'Юрист с функциями администратора': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 35000}},
#  {'Консультант по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Торговый представитель': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Пикчер': {'currency': 'RUR', 'from': None, 'gross': False, 'to': 100000}},
#  {'Менеджер по продажам выставочного зала': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Account manager (Sport marketing)': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по охране труда и технике безопасности': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': None}},
#  {'SMM-специалист': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 50000}},
#  {'Офис-менеджер': {'currency': 'RUR',
#    'from': 12000,
#    'gross': False,
#    'to': 25000}},
#  {'Водитель Газели': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по персоналу (Чемпионат мира по футболу 2018)': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 40000}},
#  {'Водитель такси': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': 140000}},
#  {'Оператор call-центра на Чемпионат мира по футболу': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 30000}},
#  {'Бухгалтер': {'currency': 'RUR', 'from': 30000, 'gross': False, 'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 300000}},
#  {'Учитель английского языка': None},
#  {'Ведущий специалист ОМТС (44-ФЗ)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': None}},
#  {'Ведущий специалист отдела юридического сопровождения закупочных процедур (44-ФЗ)': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': None}},
#  {'Выпускающий редактор журнала Банзай': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Ведущий специалист по закупкам IT оборудования': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': None}},
#  {'Косметолог-эстетист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 50000}}]

# %%
mes=[]
mes = [i for i in mas if [k for k in i if i[k]!= None]]
mes
# Out:
# [{'Менеджер по рекламе и маркетингу': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-консультант YOTA': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Электросварщик на автоматических и полуавтоматических машинах': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 19000,
#    'gross': False,
#    'to': 25000}},
#  {'Шлифовщик': {'currency': 'RUR', 'from': 35000, 'gross': True, 'to': 45000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Территориальный менеджер (салоны Билайн)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Медсестра': {'currency': 'RUR', 'from': 25000, 'gross': False, 'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Менеджер по продажам септиков': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Инженер отдела организации и планирования ПИР': {'currency': 'RUR',
#    'from': 26000,
#    'gross': False,
#    'to': None}},
#  {'Водитель-курьер': {'currency': 'RUR',
#    'from': 12000,
#    'gross': False,
#    'to': 15000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Ведущий инженер': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Ведущий инженер отдела экологической и промышленной безопасности': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Инженер (1 категория)': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Инженер/инженер отдела инженерных изысканий (2 категория)': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Инженер': {'currency': 'RUR', 'from': 25000, 'gross': None, 'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Инженер отдела мониторинга технологических процессов': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 23000,
#    'gross': None,
#    'to': 23000}},
#  {'Кредитный специалист (м. Речной вокзал)': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': 28000}},
#  {'Кредитный специалист (м. Купчино)': {'currency': 'RUR',
#    'from': 23000,
#    'gross': None,
#    'to': 25000}},
#  {'Кредитный специалист (м. Садовая)': {'currency': 'RUR',
#    'from': 23000,
#    'gross': None,
#    'to': None}},
#  {'Специалист по кредитованию': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Администратор региона': {'currency': 'RUR',
#    'from': 19000,
#    'gross': False,
#    'to': 22000}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 28000}},
#  {'Кредитный специалист (ЧМЗ)': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Администратор региона': {'currency': 'RUR',
#    'from': 21000,
#    'gross': False,
#    'to': 23000}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Ведущий инженер отдела геологии и подсчета запасов': {'currency': 'RUR',
#    'from': 35000,
#    'gross': None,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Руководитель группы гидрогеологов отдела гидрогеологии': {'currency': 'RUR',
#    'from': 35000,
#    'gross': None,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'BYR',
#    'from': 500,
#    'gross': True,
#    'to': 650}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Специалист отдела информационного обслуживания (ВТБ)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Руководитель группы гидрогеологов (Отдел гидродинамического моделирования)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по работе с клиентами': {'currency': 'BYR',
#    'from': 400,
#    'gross': False,
#    'to': 1000}},
#  {'Специалист контакт-центра (Банк ВТБ)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Ведущий инженер отдела мониторинга разработки': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Главный менеджер по развитию ипотечного кредитования': {'currency': 'RUR',
#    'from': 30700,
#    'gross': True,
#    'to': None}},
#  {'Повар': {'currency': 'RUR', 'from': 20000, 'gross': False, 'to': 25000}},
#  {'Менеджер по продажам и обслуживанию / Продавец-консультант в салон "Ростелеком" (м. Чкаловская)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 50000}},
#  {'Сварщик, помощник сварщика': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 35000}},
#  {'Менеджер по туризму': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': 40000}},
#  {'Менеджер по персоналу': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Креативный дизайнер': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 120000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по таргетированной рекламе': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Ведущий специалист по контекстной рекламе': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Ассистент аккаунт-менеджера': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 35000}},
#  {'Account Manager/Аккаунт Менеджер': {'currency': 'RUR',
#    'from': 130000,
#    'gross': True,
#    'to': 150000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 12000,
#    'gross': True,
#    'to': 40000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Администратор салона красоты': {'currency': 'BYR',
#    'from': 200,
#    'gross': True,
#    'to': None}},
#  {'Арматурщик (Российская Федерация)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Специалист по продажам': {'currency': 'BYR',
#    'from': 350,
#    'gross': True,
#    'to': 800}},
#  {'Плотник-бетонщик (в РФ)': {'currency': 'USD',
#    'from': 1000,
#    'gross': False,
#    'to': 1330}},
#  {'Водитель на авто компании, Киев': {'currency': 'UAH',
#    'from': 10000,
#    'gross': False,
#    'to': 18000}},
#  {'Автомеханик': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 60000}},
#  {'Водитель дорожной техники (категории С, D, Е) на машину КАМАЗ/КАМАЗ с прицепом в РФ': {'currency': 'RUR',
#    'from': 48000,
#    'gross': True,
#    'to': 80000}},
#  {'Водитель дорожной техники с кат.В для работы в РФ': {'currency': 'RUR',
#    'from': 48000,
#    'gross': False,
#    'to': 80000}},
#  {'Каменщик (в РФ)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Облицовщик-плиточник (в РФ)': {'currency': 'USD',
#    'from': 1000,
#    'gross': False,
#    'to': 2000}},
#  {'Монтажник сантехсистем и оборудования (сантехник) в РФ': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Гипсокартонщик / Плотник-отделочник в РФ': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 80000}},
#  {'Менеджер оптового отдела продаж': {'currency': 'RUR',
#    'from': 45000,
#    'gross': True,
#    'to': 70000}},
#  {'Специалист по работе с недвижимостью': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': {'currency': 'RUR',
#    'from': 50,
#    'gross': False,
#    'to': 80}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Начальник строительного участка': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 80000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант в магазин нижнего белья': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 30000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 40000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Производитель работ ( монолитные работы)': {'currency': 'RUR',
#    'from': 65000,
#    'gross': False,
#    'to': 65000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 25000}},
#  {'Разнорабочий в столярную мастерскую': {'currency': 'BYR',
#    'from': 400,
#    'gross': False,
#    'to': 400}},
#  {'Мастер по сварке': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': 110000}},
#  {'Риэлтор на входящие заявки': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 75000}},
#  {'Менеджер по персоналу': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Парикмахер-универсал': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Специалист лазерной эпиляции': {'currency': 'RUR',
#    'from': 24000,
#    'gross': False,
#    'to': None}},
#  {'Швея-портной в магазин ткани': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-кассир (ТК "Авеню") м. Проспект Просвещения': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Менеджер по товару / Кладовщик (ТЦ "Сити")': {'currency': 'RUR',
#    'from': 26000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по товару / Кладовщик': {'currency': 'RUR',
#    'from': 27000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТК "Континент Бухарестская")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Методолог Корпоративные Кредиты': {'currency': 'RUR',
#    'from': 200000,
#    'gross': False,
#    'to': 250000}},
#  {'Менеджер по товару в ТК "Ярмарка"': {'currency': 'RUR',
#    'from': None,
#    'gross': True,
#    'to': 26000}},
#  {'Менеджер по товару (в ТК "Охта Молл")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по товару в ТК Меркурий': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Заместитель директора магазина (Спб)': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по товару в ТЦ "Cubus", Гатчина': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТК "Фиолент")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-флорист': {'currency': 'RUR',
#    'from': 7500,
#    'gross': False,
#    'to': 12000}},
#  {'Продавец-кассир товаров для детей (в ТК "Мега Дыбенко")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТРК "Мега ПАРНАС")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Главный бухгалтер': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 50000}},
#  {'Продавец-кассир (ТРК "Французский бульвар")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Акваполис")': {'currency': 'RUR',
#    'from': 22000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Апельсин")': {'currency': 'RUR',
#    'from': 24000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Европолис")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Карусель" Савушкина 116)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Лондон Молл")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Макси")': {'currency': 'RUR',
#    'from': 26000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "РИО")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир (ТЦ "Сити молл")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Электромонтажник': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 70000}},
#  {'Продавец-кассир (ТЦ "Титан Арена")': {'currency': 'RUR',
#    'from': 27000,
#    'gross': True,
#    'to': None}},
#  {'Специалист отдела снабжения': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 120000}},
#  {'Продавец-кассир (ТЦ "Южный")': {'currency': 'RUR',
#    'from': 27000,
#    'gross': True,
#    'to': None}},
#  {'Продавец (ТК "Балкания Nova")': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Продавец товаров для детей': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Бухгалтер': {'currency': 'RUR',
#    'from': 43000,
#    'gross': False,
#    'to': 52000}},
#  {'Заместитель руководителя по работе с регионами': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 35000}},
#  {'Менеджер по работе с ключевыми клиентами': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 150000}},
#  {'Бровист': {'currency': 'RUR', 'from': 50000, 'gross': False, 'to': None}},
#  {'Няня': {'currency': 'UAH', 'from': 16000, 'gross': False, 'to': 26000}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 17000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 17000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист (м. Старая Деревня)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Региональный менеджер по продажам': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 50000}},
#  {'Кредитный специалист (м. Проспект Просвещения)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Консультант (помощник) нотариуса': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 50000}},
#  {'Кредитный специалист (м.Проспект Большевиков)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Quality Assurance Engineer': {'currency': 'USD',
#    'from': 800,
#    'gross': True,
#    'to': 1300}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 14000,
#    'gross': False,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Кредитный специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 45000,
#    'gross': True,
#    'to': None}},
#  {'Специалист линии поддержки англоговорящих клиентов': {'currency': 'RUR',
#    'from': 24000,
#    'gross': True,
#    'to': 40000}},
#  {'Агент по продажам жилой недвижимости': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Специалист отдела по расследованию мошеннических и спорных операций': {'currency': 'RUR',
#    'from': 27000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 150000}},
#  {'Су-шеф': {'currency': 'RUR', 'from': 60000, 'gross': False, 'to': 60000}},
#  {'Продавец консультант': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 40000}},
#  {'Менеджер по продажам строительных материалов': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Сварщик НАКС': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Оформитель документов': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': None}},
#  {'Сервис-консультант СК Режим (проспект Героев, проспект Молодежный, ул. Щербакова)': {'currency': 'RUR',
#    'from': 36000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер отдела продаж': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 80000}},
#  {'Ведущий инженер по слаботочным системам и автоматике': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 150000}},
#  {'Мастер ногтевого сервиса': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 40000}},
#  {'Бармен-официант': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 40000}},
#  {'Фармацевт-провизор': {'currency': 'RUR',
#    'from': 18000,
#    'gross': False,
#    'to': 22000}},
#  {'Технический специалист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 50000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Мастер ногтевого сервиса': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 120000}},
#  {'Менеджер по оптовым продажам': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': None}},
#  {'Машинист катка дорожного/асфальтового': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 70000}},
#  {'Официант-бармен': {'currency': 'BYR',
#    'from': 450,
#    'gross': True,
#    'to': None}},
#  {'Водитель': {'currency': 'RUR', 'from': 30000, 'gross': False, 'to': 40000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Ведущий PHP/JS разработчик': {'currency': 'RUR',
#    'from': 110000,
#    'gross': False,
#    'to': 150000}},
#  {'Помощник руководителя': {'currency': 'RUR',
#    'from': 43000,
#    'gross': True,
#    'to': 47000}},
#  {'Middle Front-end developer/верстальщик': {'currency': 'USD',
#    'from': 1200,
#    'gross': True,
#    'to': 1800}},
#  {'Руководитель отдела продаж отопительного оборудования': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант/кассир-продавец': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': None}},
#  {'Бухгалтер': {'currency': 'RUR', 'from': 45000, 'gross': False, 'to': None}},
#  {'Менеджер ресторана': {'currency': 'RUR',
#    'from': 55000,
#    'gross': False,
#    'to': None}},
#  {'Водитель такси на личном автомобиле': {'currency': 'BYR',
#    'from': 1000,
#    'gross': True,
#    'to': 2000}},
#  {'Водитель-экспедитор с личным грузовым автомобилем от 1,5 до 2 тонн': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 50000}},
#  {'Водитель-экспедитор с личным грузовым автомобилем от 1,5 до 2 тонн': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 60000}},
#  {'Грузчик': {'currency': 'RUR', 'from': 20000, 'gross': False, 'to': 27000}},
#  {'Менеджер отдела продаж': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': 90000}},
#  {'Водитель-экспедитор с личным грузовым автомобилем (от 1,5 до 2 тонн, будка)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 48000}},
#  {'Бухгалтер': {'currency': 'RUR', 'from': 23000, 'gross': False, 'to': None}},
#  {'Повар универсал': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 50000}},
#  {'Медицинская сестра': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Секретарь-делопроизводитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 35000}},
#  {'Веб-дизайнер': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Слесарь механосборочных работ': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 65000}},
#  {'Python разработчик': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': 110000}},
#  {'Помощник коммерческого директора': {'currency': 'RUR',
#    'from': 19000,
#    'gross': True,
#    'to': 35000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 35000}},
#  {'Старший специалист/Ведущий специалист отдела продаж ипотечных продуктов': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Специалист отдела продаж ипотечных кредитов (старший/главный)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 55000}},
#  {'SMM-менеджер(банк)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': 100000}},
#  {'Ведущий специалист Информационного центра': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 45000}},
#  {'Кассир-операционист': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 32000}},
#  {'Старший/ведущий специалист отдела продаж ипотечных продуктов': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': None}},
#  {'Старший/ведущий специалист отдела продаж ипотечных продуктов': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': None}},
#  {'Старший юрисконсульт Отдела судебного взыскания (направление – судебное взыскание)': {'currency': 'RUR',
#    'from': 65000,
#    'gross': True,
#    'to': 72000}},
#  {'Юрисконсульт Отдела правового сопровождения кредитования и розничного бизнеса': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': 70000}},
#  {'Директор по развитию ипотечного кредитования': {'currency': 'RUR',
#    'from': 150000,
#    'gross': True,
#    'to': 180000}},
#  {'Руководитель отдела по работе с партнерами': {'currency': 'RUR',
#    'from': 55000,
#    'gross': True,
#    'to': 90000}},
#  {'Старший специалист группы Процессинга': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Кассир-операционист': {'currency': 'RUR',
#    'from': 23000,
#    'gross': True,
#    'to': 23000}},
#  {'Главный/ведущий специалист/заместитель Руководителя Управление внутреннего аудита': {'currency': 'RUR',
#    'from': 87000,
#    'gross': True,
#    'to': 87000}},
#  {'Инженер-сметчик': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по продажам': {'currency': 'UZS',
#    'from': 1000000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 60000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 25000}},
#  {'SMM-маркетинг менеджер': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер проектов': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Бармен/Бариста': {'currency': 'BYR',
#    'from': 400,
#    'gross': True,
#    'to': None}},
#  {'Сотрудник Росгвардии': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 60000}},
#  {'Повар': {'currency': 'BYR', 'from': 500, 'gross': True, 'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер отдела закупок': {'currency': 'RUR',
#    'from': 65000,
#    'gross': False,
#    'to': 85000}},
#  {'Разработчик React Native': {'currency': 'RUR',
#    'from': 150000,
#    'gross': False,
#    'to': None}},
#  {'Бармен,официант,повар,администратор,кальянщик,кухонный рабочий': {'currency': 'BYR',
#    'from': 300,
#    'gross': True,
#    'to': 500}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 30000}},
#  {'Водитель в отель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Автослесарь': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по работе с дистрибьюторами и аптечными сетями': {'currency': 'RUR',
#    'from': 220000,
#    'gross': True,
#    'to': None}},
#  {'Frontend-разработчик / HTML-верстальщик': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Директор типографии': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 100000}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 8000,
#    'gross': True,
#    'to': 20000}},
#  {'Кассир (г. Красноармейск)': {'currency': 'RUR',
#    'from': 24000,
#    'gross': False,
#    'to': 43000}},
#  {'Менеджер по работе с клиентами (образование за рубежом)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Администратор салона красоты': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 20000}},
#  {'Кассир, г. Егорьевск': {'currency': 'RUR',
#    'from': 22000,
#    'gross': False,
#    'to': 43000}},
#  {'Педагог классического танца\\Педагог развития данных': {'currency': 'RUR',
#    'from': 1000,
#    'gross': False,
#    'to': 1500}},
#  {'Бармен': {'currency': 'RUR', 'from': 40000, 'gross': False, 'to': None}},
#  {'Помощник менеджера по продажам': {'currency': 'BYR',
#    'from': 400,
#    'gross': False,
#    'to': 600}},
#  {'Парикмахер': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 100000}},
#  {'Менеджер по продажам услуг': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 70000}},
#  {'Руководитель отдела продаж': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 200000}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Личный помощник руководителя / Персональный ассистент': {'currency': 'RUR',
#    'from': None,
#    'gross': True,
#    'to': 287649}},
#  {'Помощник менеджера по продажам': {'currency': 'RUR',
#    'from': 10000,
#    'gross': False,
#    'to': 25000}},
#  {'Бухгалтер': {'currency': 'RUR', 'from': 25000, 'gross': True, 'to': None}},
#  {'Водитель Uber на авто компании': {'currency': 'BYR',
#    'from': 750,
#    'gross': False,
#    'to': 1300}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Бариста': {'currency': 'BYR', 'from': 550, 'gross': False, 'to': 700}},
#  {'Ведущий разработчик Java': {'currency': 'RUR',
#    'from': 120000,
#    'gross': True,
#    'to': 220000}},
#  {'Экспедитор (Водитель)': {'currency': 'BYR',
#    'from': 700,
#    'gross': False,
#    'to': 700}},
#  {'Кредитный консультант': {'currency': 'RUR',
#    'from': 28000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по кредитованию': {'currency': 'RUR',
#    'from': 36000,
#    'gross': True,
#    'to': 60000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': None}},
#  {'HTML-верстальщик': {'currency': 'RUR',
#    'from': 90000,
#    'gross': True,
#    'to': None}},
#  {'Водитель МАЗ бункеровоз': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер торгового зала / Спорт-лидер (спортивные товары, м. Фили)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': 100000}},
#  {'Менеджер торгового зала / Спорт-лидер (спортивные товары, м. Пражская)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': 100000}},
#  {'Дизайнер-консультант / Менеджер по продажам без опыта (кухонная мебель, ТЦ Красный Кит)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Дизайнер-консультант / Менеджер по продажам без опыта (кухонная мебель, ТЦ Красный Кит)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Дизайнер-консультант/Менеджер по продажам (кухонная мебель, ТЦ Красный Кит)': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер торгового сектора/Спорт-лидер (спортивные товары, м. Юго-Западная)': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 100000}},
#  {'Контент менеджер (Маркетинг) / Специалист по рекламе': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Мастер отделочных работ / Отделочник': {'currency': 'RUR',
#    'from': 25,
#    'gross': False,
#    'to': 40}},
#  {'Начальника отдела кадров': {'currency': 'KZT',
#    'from': 150000,
#    'gross': True,
#    'to': None}},
#  {'Парикмахер-универсал': {'currency': 'RUR',
#    'from': 85000,
#    'gross': False,
#    'to': 160000}},
#  {'Официант': {'currency': 'RUR', 'from': 40000, 'gross': None, 'to': None}},
#  {'Менеджер по продажам профессиональной косметики для волос': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 150000}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Продавец-консультант электрики': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': None}},
#  {'Помощник руководителя отдела по подбору персонала': {'currency': 'RUR',
#    'from': None,
#    'gross': True,
#    'to': 65000}},
#  {'Водитель КаМаз ФАУН мусоровоз': {'currency': 'RUR',
#    'from': 45000,
#    'gross': False,
#    'to': None}},
#  {'Вечерний Консультант 1С': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 15000}},
#  {'Web-дизайнер': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': 70000}},
#  {'Менеджер по оптовым продажам инженерной сантехники': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 140000}},
#  {'Няня': {'currency': 'RUR', 'from': 60000, 'gross': False, 'to': 70000}},
#  {'Тренер-технолог/Технолог-колорист': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Руководитель проекта (дорожное строительство)': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 55000}},
#  {'Юрист': {'currency': 'RUR', 'from': 70000, 'gross': False, 'to': 90000}},
#  {'Менеджер по продаже услуг': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Начинающий специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Начинающий специалист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам сервиса онлайн-записи': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 100000}},
#  {'Junior Documentation Manager': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': 20000}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Export Documentation Manager': {'currency': 'RUR',
#    'from': 18000,
#    'gross': True,
#    'to': 30000}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Маляр по дереву': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 45000}},
#  {'Полицейский - водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Помощник бухгалтера по документам': {'currency': 'RUR',
#    'from': 12000,
#    'gross': False,
#    'to': 15000}},
#  {'Полицейский водитель': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': None}},
#  {'Региональный представитель портала недвижимости': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 70000}},
#  {'Региональный представитель портала недвижимости': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 60000}},
#  {'Оператор call-центра': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант детского магазина': {'currency': 'KZT',
#    'from': 50000,
#    'gross': True,
#    'to': 100000}},
#  {'Администратор стоматологической клиники': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам и обслуживанию / Продавец-консультант в салон "Ростелеком" (м. Адмиралтейская)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 50000}},
#  {'Территориальный торговый представитель (Ярославль, Кострома и области)': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Инженер ПТО по сварочно-монтажным работам': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Водитель-экспедитор': {'currency': 'BYR',
#    'from': 1200,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 200000}},
#  {'Врач-рентгенолог МРТ и КТ': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 100000}},
#  {'Помощник юриста': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 30000}},
#  {'Специалист по продажам': {'currency': 'BYR',
#    'from': 800,
#    'gross': True,
#    'to': None}},
#  {'Администратор фитнес студии': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Специалист технической поддержки': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 28000}},
#  {'Менеджер по продажам оптового отдела': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 100000}},
#  {'Повар холодного цеха': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 40000}},
#  {'Продавец-кассир': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 45000}},
#  {'Преподаватель испанского/английского языков': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 75000}},
#  {'Администратор отеля': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 40000}},
#  {'Автоэлектрик': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Столяр-станочник / Столяр-мебельщик': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': None}},
#  {'Старший рекрутер, hr-специалист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 80000}},
#  {'Дизайнер-консультант по шторам, обоям': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': None}},
#  {'Офис-менеджер/менеджер': {'currency': 'UAH',
#    'from': None,
#    'gross': False,
#    'to': 8000}},
#  {'Товаровед-оценщик в ломбард': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 60000}},
#  {'Менеджер по продажам в отель': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 50000}},
#  {'Помощник мастера, оператор чесального оборудования': {'currency': 'BYR',
#    'from': 800,
#    'gross': True,
#    'to': None}},
#  {'Специалист планово-экономического отдела': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Бармен-кассир': {'currency': 'RUR',
#    'from': 38000,
#    'gross': True,
#    'to': None}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': False,
#    'to': None}},
#  {'Пекарь-кондитер': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 35000}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': False,
#    'to': None}},
#  {'Менеджер / Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 39000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по администрированию и ведению проектов': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 60000}},
#  {'Электромонтажник': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 60000}},
#  {'Специалист по администрированию и ведению проектов': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 60000}},
#  {'Менеджер по работе с корпоративными клиентами': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 75000}},
#  {'Повар на завтраки': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 37000}},
#  {'Специалист по администрированию и ведению проектов': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 60000}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': True,
#    'to': None}},
#  {'Монтажник оборудования связи': {'currency': 'BYR',
#    'from': 400,
#    'gross': False,
#    'to': None}},
#  {'Консультант 1С/Аналитик 1с': {'currency': 'RUR',
#    'from': 120000,
#    'gross': False,
#    'to': 155000}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': False,
#    'to': None}},
#  {'Директор по продажам IT проектов.': {'currency': 'RUR',
#    'from': 150000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по продажам услуг': {'currency': 'UAH',
#    'from': 5000,
#    'gross': True,
#    'to': 15000}},
#  {'Менеджер по продажам услуг': {'currency': 'UAH',
#    'from': 5000,
#    'gross': True,
#    'to': 15000}},
#  {'Інспектор прикордонної служби': {'currency': 'UAH',
#    'from': 7250,
#    'gross': False,
#    'to': None}},
#  {'Торговый представитель': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 150000}},
#  {'Инженер ПТО (дорожное строительство)': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Клубный промоутер': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 80000}},
#  {'Брокер по коммерческой недвижимости': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 200000}},
#  {'Мерчендайзер': {'currency': 'UAH',
#    'from': 5000,
#    'gross': False,
#    'to': None}},
#  {'Официант': {'currency': 'RUR', 'from': 35000, 'gross': False, 'to': 40000}},
#  {'Вечерний секретарь': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 50000}},
#  {'Инженер ПТО': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 60000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': None}},
#  {'Преподаватель английского языка': {'currency': 'KZT',
#    'from': 150000,
#    'gross': False,
#    'to': 300000}},
#  {'Повар-кондитер': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 40000}},
#  {'Ведущий инженер по качеству (Senior Manual QA Engineer)': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': 130000}},
#  {'Промоутер-распространитель': {'currency': 'RUR',
#    'from': 11000,
#    'gross': False,
#    'to': 20000}},
#  {'Финансист-экономист': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 40000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Администратор СПА-салона': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 60000}},
#  {'Су-шеф (повар-универсал)': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Коренщица/коренщик': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 36000}},
#  {'Менеджер по маркетингу и PR': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'С# - разработчик': {'currency': 'RUR',
#    'from': 100000,
#    'gross': True,
#    'to': 150000}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 50000}},
#  {'HR Менеджер по подбору персонала': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 60000}},
#  {'Продавец-консультант': {'currency': 'UAH',
#    'from': None,
#    'gross': False,
#    'to': 6000}},
#  {'Старший бухгалтер-экономист': {'currency': 'KZT',
#    'from': 95000,
#    'gross': True,
#    'to': 150000}},
#  {'Офис-менеджер': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 55000}},
#  {'Монтажник лифтов': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 115000}},
#  {'Юрисконсульт (Россошь)': {'currency': 'RUR',
#    'from': 24000,
#    'gross': False,
#    'to': None}},
#  {'Промоутер-распространитель': {'currency': 'RUR',
#    'from': 11000,
#    'gross': False,
#    'to': 20000}},
#  {'Lead Developer': {'currency': 'USD',
#    'from': 3000,
#    'gross': True,
#    'to': 3600}},
#  {'Lead Developer': {'currency': 'USD',
#    'from': 3000,
#    'gross': True,
#    'to': 3600}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 120000}},
#  {'Руководитель отдела продаж': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': 170000}},
#  {'Бухгалтер 1 категории': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по подготовке тендерной документации (ФЗ 223, ФЗ 44)': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 100000}},
#  {'Web разработчик (python) / руководитель группы': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': 120000}},
#  {'Помощник юриста': {'currency': 'RUR',
#    'from': 12000,
#    'gross': False,
#    'to': 15000}},
#  {'Менеджер по продажам мебели': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам мебели': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам мебели': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Сомелье': {'currency': 'RUR', 'from': 40000, 'gross': False, 'to': 40000}},
#  {'Менеджер по продажам мебели': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Бариста': {'currency': 'RUR', 'from': 20000, 'gross': False, 'to': 30000}},
#  {'Делопроизводитель / Офис Менеджер в офис (интернет-магазин)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по продажам мебели': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам мебели': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам мебели': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Официант в коктейльный бар': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 60000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 100000}},
#  {'Ruby on Rails backend разработчик': {'currency': 'RUR',
#    'from': 115000,
#    'gross': True,
#    'to': None}},
#  {'Инженер ПТО в сфере строительства АСУДД и светофорных объектов': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': None}},
#  {'Заместитель директора розницы': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Администратор в сауну': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 65000}},
#  {'Автослесарь': {'currency': 'BYR', 'from': 900, 'gross': False, 'to': 1800}},
#  {'Организатор фестиваля': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 60000}},
#  {'Ведущий менеджер по продажам': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 80000}},
#  {'Помощник главного бухгалтера': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 60000}},
#  {'Курьер на личном автомобиле': {'currency': 'BYR',
#    'from': 700,
#    'gross': False,
#    'to': 800}},
#  {'Продавец-консультант в отдел косметики': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': 20000}},
#  {'Продавец-консультант "Forest-Home" (Апраксин переулок)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 45000}},
#  {'Электросварщик ручной сварки (6 разряд)': {'currency': 'RUR',
#    'from': 29300,
#    'gross': True,
#    'to': 29300}},
#  {'Резчик / оператор бобинорезательного оборудования в типографию': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Помощник мастера по наращиванию волос': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Слесарь-ремонтник металлургического оборудования': {'currency': 'RUR',
#    'from': 23000,
#    'gross': True,
#    'to': 30000}},
#  {'Специалист по закупкам и снабжению': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 100000}},
#  {'Лаборант по отбору проб пыли и газов': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 20000}},
# ...
#    'gross': False,
#    'to': 60000}},
#  {'Врач травматолог-ортопед (Екатеринбург)': {'currency': 'RUR',
#    'from': 39000,
#    'gross': False,
#    'to': 60000}},
#  {'Врач травматолог-ортопед (Екатеринбург)': {'currency': 'RUR',
#    'from': 39000,
#    'gross': False,
#    'to': 60000}},
#  {'Врач травматолог-ортопед (Екатеринбург)': {'currency': 'RUR',
#    'from': 39000,
#    'gross': False,
#    'to': 60000}},
#  {'Экономист (Екатеринбург)': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 26000}},
#  {'Врач-терапевт участковый (Поликлиника, ул.Удельная)': {'currency': 'RUR',
#    'from': 65000,
#    'gross': False,
#    'to': 85000}},
#  {'Врач по паллиативной медицинской помощи выездной службы (Екатеринбург)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 40000}},
#  {'Врач-хирург (Екатеринбург)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 40000}},
#  {'Инструктор-кинолог отдела охраны': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Младший инспектор отдела охраны': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант выходного дня': {'currency': 'RUR',
#    'from': 13000,
#    'gross': False,
#    'to': 15000}},
#  {'Портной': {'currency': 'BYR', 'from': 800, 'gross': True, 'to': None}},
#  {'Помощник автомаляра/ слесарь': {'currency': 'RUR',
#    'from': 15000,
#    'gross': False,
#    'to': None}},
#  {'Инженер-конструктор (машиностроение)': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 80000}},
#  {'Backend/PHP разработчик Middle': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Консультант-разработчик Siebel CRM': {'currency': 'RUR',
#    'from': 100000,
#    'gross': False,
#    'to': None}},
#  {'Водитель на автомобиль компании Hyundai Solaris Nissan Almera': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 150000}},
#  {'Региональный менеджер по работе с ключевыми клиентами': {'currency': 'RUR',
#    'from': 45000,
#    'gross': True,
#    'to': 120000}},
#  {'Менеджер по работе с ключевыми клиентами': {'currency': 'RUR',
#    'from': 45000,
#    'gross': True,
#    'to': 120000}},
#  {'Преподаватель английского языка': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 50000}},
#  {'Пекарь': {'currency': 'BYR', 'from': 700, 'gross': True, 'to': None}},
#  {'Бариста/кассир': {'currency': 'RUR',
#    'from': 28000,
#    'gross': False,
#    'to': 38000}},
#  {'Программист 1С': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 80000}},
#  {'Менеджер по продажам - консультант/секретарь': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 200000}},
#  {'Секретарь-делопроизводитель': {'currency': 'RUR',
#    'from': 75000,
#    'gross': False,
#    'to': 85000}},
#  {'IT and Digital Programs Coordinator': {'currency': 'RUR',
#    'from': 78000,
#    'gross': True,
#    'to': None}},
#  {'Мерчендайзер-консультант на электроинструмент мирового бренда': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 21693}},
#  {'Специалист направления мотивации и оплаты труда/C&B': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Промоутер-консультант (бытовая техника Midea)': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 65000}},
#  {'Медиа-байер / специалист по закупке трафика': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 70000}},
#  {'Продавец-консультант (техника GARDENA)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант (Gardena)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Разработчик C++': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': None}},
#  {'Продавец-кассир магазина обуви': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 40000}},
#  {'Помощник руководителя/менеджер': {'currency': 'UAH',
#    'from': 10000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер IT-проектов': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 120000}},
#  {'Продавец-консультант в ТЦ': {'currency': 'RUR',
#    'from': 25000,
#    'gross': None,
#    'to': 35000}},
#  {'Менеджер по работе со студентами': {'currency': 'RUR',
#    'from': 44000,
#    'gross': True,
#    'to': 48000}},
#  {'Маркетолог (блогер)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': None}},
#  {'Техник-универсал': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Разработчик C++': {'currency': 'RUR',
#    'from': 90000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по корпоративным продажам': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': 80000}},
#  {'Менеджер по работе с корпоративными клиентами': {'currency': 'RUR',
#    'from': 52000,
#    'gross': True,
#    'to': 70000}},
#  {'Торговый представитель': {'currency': 'RUR',
#    'from': 24000,
#    'gross': True,
#    'to': 40000}},
#  {'Монтажник': {'currency': 'RUR', 'from': 25000, 'gross': True, 'to': 55000}},
#  {'Руководитель отдела аренды': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': None}},
#  {'Оператор печатного оборудования': {'currency': 'RUR',
#    'from': 15000,
#    'gross': True,
#    'to': 25000}},
#  {'Секретарь на ресепшен': {'currency': 'RUR',
#    'from': 22000,
#    'gross': None,
#    'to': 26000}},
#  {'Дизайнер': {'currency': 'RUR', 'from': 25000, 'gross': False, 'to': 35000}},
#  {'Менеджер по работе с клиентами (в сервисный центр)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': True,
#    'to': 23000}},
#  {'Менеджер по работе с клиентами (производственное направление)': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': 105000}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Инженер-конструктор': {'currency': 'RUR',
#    'from': 35000,
#    'gross': True,
#    'to': 45000}},
#  {'Разработчик C++': {'currency': 'RUR',
#    'from': 100000,
#    'gross': True,
#    'to': None}},
#  {'Помощник установщика': {'currency': 'RUR',
#    'from': 30000,
#    'gross': None,
#    'to': 45000}},
#  {'Product Designer/Дизайнер продукта': {'currency': 'RUR',
#    'from': 80000,
#    'gross': True,
#    'to': None}},
#  {'Product Designer/Дизайнер продукта': {'currency': 'RUR',
#    'from': 80000,
#    'gross': True,
#    'to': None}},
#  {'Product Designer/Дизайнер продукта': {'currency': 'RUR',
#    'from': 80000,
#    'gross': True,
#    'to': None}},
#  {'Менеджер по продажам в интернет-магазин (секс шоп)': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 50000}},
#  {'Водитель такси': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 150000}},
#  {'Разработчик C++': {'currency': 'RUR',
#    'from': 115000,
#    'gross': True,
#    'to': None}},
#  {'Административный помощник': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Ведущий менеджер по туризму CORAL TRAVEL': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 200000}},
#  {'Врач-гинеколог': {'currency': 'RUR',
#    'from': 60000,
#    'gross': False,
#    'to': 170000}},
#  {'Администратор-кассир стоматологической клиники': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 45000}},
#  {'Заместитель главного бухгалтера': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Врач-онколог': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Старший бухгалтер (взаиморасчеты с зарубежными поставщиками)': {'currency': 'RUR',
#    'from': 65000,
#    'gross': False,
#    'to': None}},
#  {'SMM-менеджер': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам новостроек': {'currency': 'RUR',
#    'from': 85000,
#    'gross': True,
#    'to': 300000}},
#  {'Фотограф': {'currency': 'RUR', 'from': 30000, 'gross': False, 'to': None}},
#  {'Фармацевт-провизор': {'currency': 'RUR',
#    'from': 25000,
#    'gross': True,
#    'to': 35000}},
#  {'Ветеринарный врач': {'currency': 'RUR',
#    'from': 10000,
#    'gross': True,
#    'to': 22000}},
#  {'Менеджер отдела продаж по работе с ключевыми клиентами': {'currency': 'KZT',
#    'from': 200000,
#    'gross': False,
#    'to': 1000000}},
#  {'Охранник': {'currency': 'RUR', 'from': 40000, 'gross': False, 'to': None}},
#  {'Менеджер отдела продаж': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 200000}},
#  {'Охранник': {'currency': 'RUR', 'from': None, 'gross': True, 'to': 45000}},
#  {'Вечерний специалист по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер отдела продаж': {'currency': 'RUR',
#    'from': None,
#    'gross': True,
#    'to': 120000}},
#  {'Менеджер переводчик бюро переводов': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 40000}},
#  {'Управляющий Converse': {'currency': 'RUR',
#    'from': 55000,
#    'gross': True,
#    'to': 75000}},
#  {'Вечерний менеджер': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Закройщик': {'currency': 'BYR', 'from': 600, 'gross': False, 'to': None}},
#  {'Водитель-экспедитор': {'currency': 'RUR',
#    'from': 52000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер в отдел телефонных продаж': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Комлектовщик  (Крекшино/Бекасово)': {'currency': 'RUR',
#    'from': 52000,
#    'gross': True,
#    'to': None}},
#  {'Full-stack разработчик (PHP)': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Торговый представитель': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 55000}},
#  {'Дизайнер-иллюстратор': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 50000}},
#  {'Менеджер визового отдела': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 50000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 120000}},
#  {'Сварщик рекламных конструкций': {'currency': 'RUR',
#    'from': 50000,
#    'gross': False,
#    'to': 50000}},
#  {'Водитель-экспедитор': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 45000}},
#  {'Менеджер по туризму': {'currency': 'RUR',
#    'from': 65000,
#    'gross': False,
#    'to': 165000}},
#  {'Заместитель начальника отдела бухгалтерского учета в аудиторскую фирму': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Администратор': {'currency': 'RUR',
#    'from': 12000,
#    'gross': False,
#    'to': 15000}},
#  {'Повар на хачапури': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': None}},
#  {'Секретарь': {'currency': 'RUR', 'from': 25000, 'gross': True, 'to': None}},
#  {'Продавец-кассир': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': 35000}},
#  {'Сборщик мебели': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': None}},
#  {'Промоутер': {'currency': 'RUR', 'from': 10000, 'gross': False, 'to': None}},
#  {'Медицинский представитель': {'currency': 'RUR',
#    'from': 48000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по туризму': {'currency': 'BYR',
#    'from': 700,
#    'gross': False,
#    'to': 3000}},
#  {'Менеджер по продажам (спорт/фитнес клуб)': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 70000}},
#  {'Оператор фасовочной линии': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Помощник воспитателя в частный детский сад': {'currency': 'RUR',
#    'from': 19000,
#    'gross': False,
#    'to': None}},
#  {'Продавец-консультант': {'currency': 'RUR',
#    'from': 23000,
#    'gross': False,
#    'to': 36000}},
#  {'Комплектовщик': {'currency': 'RUR',
#    'from': 22000,
#    'gross': False,
#    'to': None}},
#  {'Администратор в Салон Красоты': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 35000}},
#  {'Водитель погрузчика': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': None}},
#  {'Водитель погрузчика': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Руководитель отдела продаж': {'currency': 'RUR',
#    'from': 50000,
#    'gross': True,
#    'to': 120000}},
#  {'Менеджер по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 80000}},
#  {'Менеджер кафе': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Официант': {'currency': 'RUR', 'from': 20000, 'gross': False, 'to': None}},
#  {'Менеджер по продажам Департамента ипотечного кредитования': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 70000}},
#  {'Специалист по бронированию': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Слесарь аварийно-восстановительных работ': {'currency': 'RUR',
#    'from': 40000,
#    'gross': True,
#    'to': None}},
#  {'PHP Developer': {'currency': 'USD',
#    'from': 1200,
#    'gross': False,
#    'to': 1800}},
#  {'Врач косметолог (дерматокосметолог)': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 120000}},
#  {'Юрист с функциями администратора': {'currency': 'RUR',
#    'from': 30000,
#    'gross': False,
#    'to': 35000}},
#  {'Консультант по работе с клиентами': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': None}},
#  {'Торговый представитель': {'currency': 'RUR',
#    'from': 35000,
#    'gross': False,
#    'to': None}},
#  {'Пикчер': {'currency': 'RUR', 'from': None, 'gross': False, 'to': 100000}},
#  {'Менеджер по продажам выставочного зала': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': None}},
#  {'Account manager (Sport marketing)': {'currency': 'RUR',
#    'from': 80000,
#    'gross': False,
#    'to': None}},
#  {'Специалист по охране труда и технике безопасности': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': None}},
#  {'SMM-специалист': {'currency': 'RUR',
#    'from': 30000,
#    'gross': True,
#    'to': 50000}},
#  {'Офис-менеджер': {'currency': 'RUR',
#    'from': 12000,
#    'gross': False,
#    'to': 25000}},
#  {'Водитель Газели': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': None}},
#  {'Менеджер по персоналу (Чемпионат мира по футболу 2018)': {'currency': 'RUR',
#    'from': 40000,
#    'gross': False,
#    'to': 40000}},
#  {'Водитель такси': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': 140000}},
#  {'Оператор call-центра на Чемпионат мира по футболу': {'currency': 'RUR',
#    'from': None,
#    'gross': False,
#    'to': 30000}},
#  {'Бухгалтер': {'currency': 'RUR', 'from': 30000, 'gross': False, 'to': None}},
#  {'Менеджер по продажам': {'currency': 'RUR',
#    'from': 70000,
#    'gross': False,
#    'to': 300000}},
#  {'Ведущий специалист ОМТС (44-ФЗ)': {'currency': 'RUR',
#    'from': 60000,
#    'gross': True,
#    'to': None}},
#  {'Ведущий специалист отдела юридического сопровождения закупочных процедур (44-ФЗ)': {'currency': 'RUR',
#    'from': 70000,
#    'gross': True,
#    'to': None}},
#  {'Выпускающий редактор журнала Банзай': {'currency': 'RUR',
#    'from': 25000,
#    'gross': False,
#    'to': 35000}},
#  {'Ведущий специалист по закупкам IT оборудования': {'currency': 'RUR',
#    'from': 90000,
#    'gross': False,
#    'to': None}},
#  {'Косметолог-эстетист': {'currency': 'RUR',
#    'from': 20000,
#    'gross': False,
#    'to': 50000}}]

# %%
mid=[]
for i in mes:
    for k in i:
        if i[k]['from'] != None and i[k]['to'] != None:
            mi={k : (int(i[k]['from'])+int(i[k]['to']))/2}
        elif i[k]['from'] == None and i[k]['to'] != None:
            mi={k:i[k]['to']}
        elif i[k]['from'] != None and i[k]['to'] == None:
            mi={k:i[k]['from']}
        mid.append(mi)

# %%
for i in range(len(mid)-1):
    for j in range(len(mid)-i):
        for k1 in mid[i].keys():
            for k2 in mid[j].keys():
                if k1<k2:
                    str=mid[j]
                    mid[j]=mid[i]
                    mid[i]=str    

mid
# Out:
# [{'.NET C# разработчик (Unity3D)': 50020.0},
#  {'Account Manager/Аккаунт Менеджер': 140000.0},
#  {'Account manager (Sport marketing)': 80000},
#  {'Backend/PHP разработчик Middle': 70000},
#  {'Cистемный администратор (Руководитель группы администраторов)': 75000.0},
#  {'Dispatch manager / Менеджер по логистике': 650.0},
#  {'Export Documentation Manager': 24000.0},
#  {'Frontend Developer': 135000.0},
#  {'Frontend-разработчик / HTML-верстальщик': 80000},
#  {'Full-stack разработчик (PHP)': 80000},
#  {'HR Менеджер по подбору персонала': 45000.0},
#  {'HTML-верстальщик': 90000},
#  {'IT and Digital Programs Coordinator': 78000},
#  {'Junior Documentation Manager': 17500.0},
#  {'Lead Developer': 3300.0},
#  {'Middle Front-end developer/верстальщик': 1500.0},
#  {'PHP Developer': 1500.0},
#  {'Product Designer/Дизайнер продукта': 80000},
#  {'Product Designer/Дизайнер продукта': 80000},
#  {'Product Designer/Дизайнер продукта': 80000},
#  {'Python разработчик': 100000.0},
#  {'Quality Assurance Engineer': 1050.0},
#  {'Ruby on Rails backend разработчик': 115000},
#  {'SEO-специалист': 32500.0},
#  {'SMM-маркетинг менеджер': 70000},
#  {'SMM-менеджер': 50000},
#  {'SMM-менеджер(банк)': 80000.0},
#  {'Senior Backend (Node.JS) Developer': 100000},
#  {'Web разработчик (python) / руководитель группы': 100000.0},
#  {'Web-дизайнер': 70000.0},
#  {'Інспектор прикордонної служби': 7250},
#  {'Інспектор прикордонної служби': 7250},
#  {'Інспектор прикордонної служби': 7250},
#  {'Інспектор прикордонної служби': 7250},
#  {'Інспектор прикордонної служби': 7250},
#  {'Автомеханик': 45000.0},
#  {'Автослесарь': 30000},
#  {'Автослесарь': 1350.0},
#  {'Автоэлектрик': 60000},
#  {'Агент по продажам жилой недвижимости': 70000},
#  {'Административный помощник': 35000},
#  {'Администратор': 13500.0},
#  {'Администратор СПА-салона': 50000.0},
#  {'Администратор в сауну': 62500.0},
#  {'Администратор отеля': 40000.0},
#  {'Администратор региона': 22000.0},
#  {'Администратор салона красоты': 200},
#  {'Администратор салона красоты': 17500.0},
#  {'Администратор стоматологической клиники': 25000},
#  {'Администратор фитнес студии': 30000.0},
#  {'Администратор-кассир стоматологической клиники': 45000},
#  {'Администратор-оператор': 30000},
#  {'Акушерка/Акушер': 25000},
#  {'Арматурщик (Российская Федерация)': 70000.0},
#  {'Ассистент аккаунт-менеджера': 32500.0},
#  {'Бариста': 25000.0},
#  {'Бариста': 625.0},
#  {'Бармен': 37500.0},
#  {'Бармен': 40000},
#  {'Бармен,официант,повар,администратор,кальянщик,кухонный рабочий': 400.0},
#  {'Бармен-кальянщик': 37500.0},
#  {'Бармен-кассир': 38000},
#  {'Бармен-официант': 35000.0},
#  {'Бармен/Бариста': 400},
#  {'Бровист': 50000},
#  {'Брокер по коммерческой недвижимости': 140000.0},
#  {'Бухгалтер': 23000},
#  {'Бухгалтер': 25000},
#  {'Бухгалтер': 47500.0},
#  {'Бухгалтер': 45000},
#  {'Бухгалтер': 27500.0},
#  {'Бухгалтер 1 категории': 25000},
#  {'Веб-дизайнер': 100000},
#  {'Веб-программист': 45000},
#  {'Ведущий PHP/JS разработчик': 130000.0},
#  {'Ведущий инженер': 25000},
#  {'Ведущий инженер отдела геологии и подсчета запасов': 35000},
#  {'Ведущий инженер отдела мониторинга разработки': 40000},
#  {'Ведущий инженер отдела экологической и промышленной безопасности': 25000},
#  {'Ведущий инженер по качеству (Senior Manual QA Engineer)': 110000.0},
#  {'Ведущий инженер по слаботочным системам и автоматике': 60000},
#  {'Ведущий инженер/главный инженер': 110000.0},
#  {'Ведущий менеджер по продажам': 60000.0},
#  {'Ведущий менеджер по туризму CORAL TRAVEL': 130000.0},
#  {'Ведущий разработчик Java': 170000.0},
#  {'Ведущий специалист по контекстной рекламе': 100000},
#  {'Ведущий специалист центрального офиса продаж': 150000},
#  {'Вечерний Консультант 1С': 15000.0},
#  {'Вечерний Консультант 1С': 15000.0},
#  {'Вечерний Консультант 1С': 15000.0},
#  {'Вечерний Консультант 1С': 15000.0},
#  {'Вечерний секретарь': 50000.0},
#  {'Водитель Uber на авто компании': 1025.0},
#  {'Водитель МАЗ бункеровоз': 45000},
#  {'Водитель дорожной техники (категории С, D, Е) на машину КАМАЗ/КАМАЗ с прицепом в РФ': 64000.0},
#  {'Водитель дорожной техники с кат.В для работы в РФ': 64000.0},
#  {'Водитель на авто компании, Киев': 14000.0},
#  {'Водитель на автомобиль компании Hyundai Solaris Nissan Almera': 110000.0},
#  {'Водитель с личным грузовым автомобилем (Рефрижератор, Изотерм, Фургон, Тент)': 75000.0},
#  {'Водитель такси': 80000.0},
#  {'Водитель такси': 50000},
#  {'Водитель такси': 60000},
#  {'Водитель такси': 34000},
#  {'Водитель такси': 40000},
#  {'Водитель такси на личном автомобиле': 1500.0},
#  {'Водитель-курьер': 13500.0},
#  {'Водитель-экспедитор': 1200},
#  {'Водитель-экспедитор с личным грузовым автомобилем': 85000.0},
#  {'Водитель-экспедитор с личным грузовым автомобилем (от 1,5 до 2 тонн, будка)': 41500.0},
#  {'Водитель-экспедитор с личным грузовым автомобилем от 1,5 до 2 тонн': 45000.0},
#  {'Водитель-экспедитор с личным грузовым автомобилем от 1,5 до 2 тонн': 50000.0},
#  {'Врач по паллиативной медицинской помощи выездной службы (Екатеринбург)': 37500.0},
#  {'Врач стоматолог-терапевт': 60000.0},
#  {'Врач травматолог-ортопед': 35000},
#  {'Врач травматолог-ортопед (Екатеринбург)': 49500.0},
#  {'Врач травматолог-ортопед (Екатеринбург)': 49500.0},
#  {'Врач травматолог-ортопед (Екатеринбург)': 49500.0},
#  {'Врач травматолог-ортопед (Екатеринбург)': 49500.0},
#  {'Врач травматолог-ортопед (Екатеринбург)': 49500.0},
#  {'Врач травматолог-ортопед (травмпункт, Екатеринбург)': 49500.0},
#  {'Врач травматолог-ортопед (травмпункт, Екатеринбург)': 49500.0},
#  {'Врач функциональной диагностики': 35000},
#  {'Врач-кардиолог': 34500.0},
#  {'Врач-кардиолог (Екатеринбург)': 34500.0},
#  {'Врач-оторин\u2062оларинголог (Екатеринбург)': 36500},
#  {'Врач-рентгенолог': 35000},
#  {'Врач-рентгенолог МРТ и КТ': 70000.0},
#  {'Врач-статистик': 35000},
#  {'Врач-терапевт (терапевтическое отделение стационара), Екатеринбург': 32000},
#  {'Врач-терапевт / семейный врач': 57500.0},
#  {'Врач-терапевт / семейный врач': 57500.0},
#  {'Врач-терапевт участковый (Поликлиника, ул.Удельная)': 75000.0},
#  {'Врач-уролог': 34250.0},
#  {'Врач-хирург (Екатеринбург)': 37500.0},
#  {'Гипсокартонщик / Плотник-отделочник в РФ': 80000.0},
#  {'Главный бухгалтер': 175000.0},
#  {'Главный инженер проекта/ ГИП': 100000.0},
#  {'Главный менеджер по развитию ипотечного кредитования': 30700},
#  {'Главный технолог/ разработчик ЛКМ': 100000},
#  {'Главный/ведущий специалист/заместитель Руководителя Управление внутреннего аудита': 87000.0},
#  {'Грузчик': 23500.0},
#  {'Грузчик-комплектовщик': 21500.0},
#  {'Делопроизводитель / Офис Менеджер в офис (интернет-магазин)': 30000},
#  {'Дизайнер-консультант / Менеджер по продажам без опыта (кухонная мебель, ТЦ Красный Кит)': 60000},
#  {'Дизайнер-консультант по шторам, обоям': 50000},
#  {'Директор по продажам IT проектов.': 150000},
#  {'Директор по развитию ипотечного кредитования': 165000.0},
#  {'Директор филиала': 160000},
#  {'Директор фитнес-клуба': 100000},
#  {'Заместитель директора магазина (Спб)': 40000},
#  {'Заместитель руководителя по работе с регионами': 35000},
#  {'Инженер (1 категория)': 25000},
#  {'Инженер ПТО (дорожное строительство)': 70000},
#  {'Инженер ПТО по сварочно-монтажным работам': 70000},
#  {'Инженер отдела организации и планирования ПИР': 26000},
#  {'Инженер по внедрению информационных систем': 55000.0},
#  {'Инженер по охране труда': 50000},
#  {'Инженер по эксплуатации теплотехнического оборудования': 70000},
#  {'Инженер-программист микроконтроллеров / Embedded engineer': 95000.0},
#  {'Инженер-проектировщик': 32500.0},
#  {'Инженер-сметчик': 50000},
#  {'Инженер-электронщик': 52500.0},
#  {'Инженер/инженер отдела инженерных изысканий (2 категория)': 25000},
#  {'Каменщик (в РФ)': 70000.0},
#  {'Кассир, г. Егорьевск': 32500.0},
#  {'Кассир-операционист': 23000.0},
#  {'Кассир-операционист': 31000.0},
#  {'Кладовщик': 42500.0},
#  {'Кладовщик': 450},
#  {'Клубный промоутер': 50000.0},
#  {'Консультант (помощник) нотариуса': 40000.0},
#  {'Контент менеджер (Маркетинг) / Специалист по рекламе': 40000},
#  {'Косметолог-эстетист': 45000.0},
#  {'Креативный дизайнер': 100000.0},
#  {'Кредитный консультант': 28000},
#  {'Кредитный специалист': 15000},
#  {'Кредитный специалист': 20000},
#  {'Кредитный специалист': 17000},
#  {'Кредитный специалист': 17000},
#  {'Кредитный специалист': 15000},
#  {'Кредитный специалист': 30000},
#  {'Кредитный специалист': 25000},
#  {'Кредитный специалист': 20000},
#  {'Кредитный специалист': 15000},
#  {'Кредитный специалист': 25000},
#  {'Кредитный специалист (ЧМЗ)': 15000},
#  {'Кредитный специалист (м. Проспект Просвещения)': 30000},
#  {'Кредитный специалист (м. Речной вокзал)': 26500.0},
#  {'Кредитный специалист (м. Садовая)': 23000},
#  {'Кредитный специалист (м.Проспект Большевиков)': 30000},
#  {'Лаборант по отбору проб пыли и газов': 20000.0},
#  {'Личный помощник руководителя': 33850.0},
#  {'Личный помощник руководителя / Персональный ассистент': 287649},
#  {'Маляр по дереву': 40000.0},
#  {'Мастер ногтевого сервиса': 95000.0},
#  {'Мастер ногтевого сервиса': 32500.0},
#  {'Мастер ногтевого сервиса': 40000},
#  {'Мастер отделочных работ / Отделочник': 32.5},
#  {'Мастер по наращиванию ресниц': 40000},
#  {'Мастер по сварке': 100000.0},
#  {'Машинист катка дорожного/асфальтового': 65000.0},
#  {'Медицинская сестра': 40000},
#  {'Медицинская сестра палатная': 25000},
#  {'Менеджер / Менеджер по работе с клиентами': 39000},
#  {'Менеджер интернет-магазина (Одежда, текстильная продукция)': 27500.0},
#  {'Менеджер оптового отдела продаж': 57500.0},
#  {'Менеджер отдела закупок': 75000.0},
#  {'Менеджер отдела продаж': 67500.0},
#  {'Менеджер отдела продаж': 55000.0},
#  {'Менеджер по кредитованию': 48000.0},
#  {'Менеджер по маркетингу и PR': 40000},
#  {'Менеджер по оптовым продажам': 45000},
#  {'Менеджер по оптовым продажам': 43500.0},
#  {'Менеджер по персоналу': 57500.0},
#  {'Менеджер по персоналу': 15000},
#  {'Менеджер по подбору персонала': 50000},
#  {'Менеджер по продажам': 175000.0},
#  {'Менеджер по продажам': 67500.0},
#  {'Менеджер по продажам': 150000},
#  {'Менеджер по продажам': 100000.0},
#  {'Менеджер по продажам': 125000.0},
#  {'Менеджер по продажам в отель': 37500.0},
#  {'Менеджер по продажам и обслуживанию / Продавец-консультант в салон "Ростелеком" (м. Чкаловская)': 40000.0},
#  {'Менеджер по продажам мебели': 30000},
#  {'Менеджер по продажам мебели': 30000},
#  {'Менеджер по продажам мебели': 30000},
#  {'Менеджер по продажам мебели': 30000},
#  {'Менеджер по продажам мебели': 30000},
#  {'Менеджер по продажам оптового отдела': 90000.0},
#  {'Менеджер по продажам профессиональной косметики для волос': 105000.0},
#  {'Менеджер по продажам септиков': 30000},
#  {'Менеджер по продажам сервиса онлайн-записи': 67500.0},
#  {'Менеджер по продажам строительных материалов': 60000},
#  {'Менеджер по продажам технической продукции': 35000},
#  {'Менеджер по продажам туристических услуг': 20000},
#  {'Менеджер по продажам услуг': 55000.0},
#  {'Менеджер по продажам услуг': 10000.0},
#  {'Менеджер по продаже услуг': 35000},
#  {'Менеджер по работе с дистрибьюторами и аптечными сетями': 220000},
#  {'Менеджер по работе с клиентами': 70000.0},
#  {'Менеджер по работе с клиентами': 27500.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 30000.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами (образование за рубежом)': 60000},
#  {'Менеджер по работе с корпоративными клиентами': 57500.0},
#  {'Менеджер по рекламе и маркетингу': 30000},
#  {'Менеджер по сопровождению программного обеспечения ОМС': 55000.0},
#  {'Менеджер по товару / Кладовщик': 27000},
#  {'Менеджер по товару / Кладовщик (ТЦ "Сити")': 26000},
#  {'Менеджер по товару в ТК "Ярмарка"': 26000},
#  {'Менеджер по товару в ТК Меркурий': 30000},
#  {'Менеджер по товару в ТЦ "Cubus", Гатчина': 30000},
#  {'Менеджер по туризму': 27500.0},
#  {'Менеджер проектов': 65000.0},
#  {'Менеджер проектов': 60000},
#  {'Менеджер ресторана': 55000},
#  {'Менеджер торгового зала / Спорт-лидер (спортивные товары, м. Пражская)': 80000.0},
#  {'Менеджер торгового зала / Спорт-лидер (спортивные товары, м. Фили)': 80000.0},
#  {'Менеджер торгового сектора/Спорт-лидер (спортивные товары, м. Юго-Западная)': 75000.0},
#  {'Методолог Корпоративные Кредиты': 225000.0},
#  {'Монтажник СКС': 50000},
#  {'Монтажник лифтов': 82500.0},
#  {'Монтажник оборудования связи': 400},
#  {'Монтажник сантехсистем и оборудования (сантехник) в РФ': 70000.0},
#  {'Начальника отдела кадров': 150000},
#  {'Начинающий специалист': 25000},
#  {'Начинающий специалист': 25000},
#  {'Няня': 21000.0},
#  {'Облицовщик-плиточник (в РФ)': 1500.0},
#  {'Организатор фестиваля': 50000.0},
#  {'Офис-менеджер': 55000.0},
#  {'Офис-менеджер': 32500.0},
#  {'Официант': 65000.0},
#  {'Официант': 40000},
#  {'Официант': 37500.0},
#  {'Официант в коктейльный бар': 50000.0},
#  {'Официант-бармен': 450},
#  {'Оформитель документов': 40000},
#  {'Парикмахер': 80000.0},
#  {'Парикмахер-универсал': 122500.0},
#  {'Парикмахер-универсал': 75000.0},
#  {'Парикмахер-универсал': 25000},
#  {'Педагог классического танца\\Педагог развития данных': 1250.0},
#  {'Плотник-бетонщик (в РФ)': 1165.0},
#  {'Повар': 22500.0},
#  {'Повар': 500},
#  {'Повар универсал': 45000.0},
#  {'Повар-кондитер': 40000},
#  {'Полицейский - водитель': 30000},
#  {'Полицейский - водитель': 30000},
#  {'Полицейский - водитель': 30000},
#  {'Полицейский - водитель': 30000},
#  {'Полиц\u200eейск\u200eий (Москва)': 45000},
#  {'Помощник SEO-специалиста / Младший SEO-оптимизатор / Интернет-маркетолог': 30000.0},
#  {'Помощник администратора сайта': 56000.0},
#  {'Помощник бухгалтера по документам': 13500.0},
#  {'Помощник коммерческого директора': 27000.0},
#  {'Помощник мастера по наращиванию волос': 40000},
#  {'Помощник менеджера по продажам': 17500.0},
#  {'Помощник менеджера по продажам': 500.0},
#  {'Помощник руководителя отдела по подбору персонала': 65000},
#  {'Помощник юриста': 13500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 22000.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 225000.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Программист C/С++': 70000.0},
#  {'Программист С++': 70000},
#  {'Продавец консультант': 27500.0},
#  {'Продавец-кассир': 32500.0},
#  {'Продавец-кассир (ТК "Континент Бухарестская")': 30000},
#  {'Продавец-кассир (ТРК "Мега ПАРНАС")': 30000},
#  {'Продавец-кассир (ТЦ "Акваполис")': 22000},
#  {'Продавец-кассир (ТЦ "Апельсин")': 24000},
#  {'Продавец-кассир (ТЦ "Карусель" Савушкина 116)': 30000},
#  {'Продавец-кассир (ТЦ "Макси")': 26000},
#  {'Продавец-кассир (ТЦ "Сити молл")': 30000},
#  {'Продавец-кассир (ТЦ "Южный")': 27000},
#  {'Продавец-кассир товаров для детей (в ТК "Мега Дыбенко")': 30000},
#  {'Продавец-консультант': 14000},
#  {'Продавец-консультант': 6000},
#  {'Продавец-консультант': 25000},
#  {'Продавец-консультант': 15000},
#  {'Продавец-консультант': 30000},
#  {'Продавец-консультант': 40000.0},
#  {'Продавец-консультант': 15000},
#  {'Продавец-консультант': 14000.0},
#  {'Продавец-консультант': 25000},
#  {'Продавец-консультант': 575.0},
#  {'Продавец-консультант "Forest-Home" (Апраксин переулок)': 37500.0},
#  {'Продавец-консультант в магазин нижнего белья': 25000.0},
#  {'Продавец-консультант в отдел косметики': 17500.0},
#  {'Продавец-консультант детского магазина': 75000.0},
#  {'Продавец-консультант электрики': 45000},
#  {'Продавец-консультант/кассир-продавец': 15000},
#  {'Продавец-флорист': 9750.0},
#  {'Производитель работ ( монолитные работы)': 65000.0},
#  {'Промоутер-распространитель': 15500.0},
#  {'Разработчик React Native': 150000},
#  {'Региональный представитель портала недвижимости': 55000.0},
#  {'Резчик / оператор бобинорезательного оборудования в типографию': 40000},
#  {'Риэлтор на входящие заявки': 45000.0},
#  {'Руководитель группы гидрогеологов отдела гидрогеологии': 35000},
#  {'Руководитель отдела продаж': 130000.0},
#  {'Руководитель отдела продаж отопительного оборудования': 70000},
#  {'С# - разработчик': 125000.0},
#  {'Сварщик, помощник сварщика': 27500.0},
#  {'Сервис-консультант СК Режим (проспект Героев, проспект Молодежный, ул. Щербакова)': 36000},
#  {'Слесарь механосборочных работ': 57500.0},
#  {'Слесарь механосборочных работ': 57500.0},
#  {'Слесарь механосборочных работ': 45000},
#  {'Слесарь механосборочных работ': 57500.0},
#  {'Слесарь механосборочных работ': 57500.0},
#  {'Сотрудник Росгвардии': 50000.0},
#  {'Специалист контакт-центра (Банк ВТБ)': 20000},
#  {'Специалист линии поддержки англоговорящих клиентов': 32000.0},
#  {'Специалист отдела по расследованию мошеннических и спорных операций': 27000},
#  {'Специалист отдела снабжения': 85000.0},
#  {'Специалист по администрированию и ведению проектов': 40000.0},
#  {'Специалист по администрированию и ведению проектов': 40000.0},
#  {'Специалист по подготовке тендерной документации (ФЗ 223, ФЗ 44)': 70000.0},
#  {'Специалист по продажам': 1000000},
#  {'Специалист по работе с клиентами': 700.0},
#  {'Специалист по таргетированной рекламе': 100000},
#  {'Старший бухгалтер-экономист': 122500.0},
#  {'Старший специалист группы Процессинга': 25000},
#  {'Старший юрисконсульт Отдела судебного взыскания (направление – судебное взыскание)': 68500.0},
#  {'Старший/ведущий специалист отдела продаж ипотечных продуктов': 35000},
#  {'Су-шеф': 60000.0},
#  {'Территориальный менеджер (салоны Билайн)': 70000.0},
#  {'Технический специалист': 35000.0},
#  {'Торговый представитель': 87500.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Фармацевт-провизор': 20000.0},
#  {'Швея-портной в магазин ткани': 15000},
#  {'Экспедитор (Водитель)': 700.0},
#  {'Электромонтажник': 47500.0},
#  {'Юрисконсульт (Россошь)': 24000},
#  {'Юрист с функциями администратора': 32500.0},
#  {'Юрисконсульт Отдела правового сопровождения кредитования и розничного бизнеса': 65000.0},
#  {'Электросварщик на автоматических и полуавтоматических машинах': 57500.0},
#  {'Электромонтажник': 65000.0},
#  {'Шлифовщик': 40000.0},
#  {'Финансист-экономист': 32500.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Тренер-технолог/Технолог-колорист': 80000},
#  {'Товаровед-оценщик в ломбард': 50000.0},
#  {'Территориальный торговый представитель (Ярославль, Кострома и области)': 40000},
#  {'Су-шеф (повар-универсал)': 30000.0},
#  {'Столяр-станочник / Столяр-мебельщик': 60000},
#  {'Старший/ведущий специалист отдела продаж ипотечных продуктов': 35000},
#  {'Старший специалист/Ведущий специалист отдела продаж ипотечных продуктов': 30000},
#  {'Старший рекрутер, hr-специалист': 50000.0},
#  {'Специалист технической поддержки': 26500.0},
#  {'Специалист по работе с недвижимостью': 35000},
#  {'Специалист по продажам': 575.0},
#  {'Специалист по продажам': 800},
#  {'Специалист по кредитованию': 15000},
#  {'Специалист по администрированию и ведению проектов': 40000.0},
#  {'Специалист планово-экономического отдела': 70000},
#  {'Специалист отдела продаж ипотечных кредитов (старший/главный)': 45000.0},
#  {'Специалист отдела информационного обслуживания (ВТБ)': 20000},
#  {'Специалист лазерной эпиляции': 24000},
#  {'Электросварщик ручной сварки (6 разряд)': 29300.0},
#  {'Сомелье': 40000.0},
#  {'Слесарь механосборочных работ': 57500.0},
#  {'Слесарь-ремонтник металлургического оборудования': 26500.0},
#  {'Специалист по закупкам и снабжению': 70000.0},
#  {'Слесарь механосборочных работ': 57500.0},
#  {'Слесарь механосборочных работ': 57500.0},
#  {'Секретарь-делопроизводитель': 32500.0},
#  {'Сварщик НАКС': 100000},
#  {'Руководитель проекта (дорожное строительство)': 100000},
#  {'Руководитель отдела продаж': 117500.0},
#  {'Руководитель отдела по работе с партнерами': 72500.0},
#  {'Руководитель группы гидрогеологов (Отдел гидродинамического моделирования)': 35000},
#  {'Юрист': 35000.0},
#  {'Региональный представитель портала недвижимости': 55000.0},
#  {'Региональный менеджер по продажам': 35000.0},
#  {'Разнорабочий в столярную мастерскую': 400.0},
#  {'Промоутер-распространитель': 15500.0},
#  {'Специалист по лазерной эпиляции': 80000},
#  {'Разработчик С++': 60000.0},
#  {'Специалист управления данными': 30000},
#  {'Специалист управления данными (в IT-компанию)': 60000},
#  {'Специалист технической поддержки (1 уровень)': 55000},
#  {'Продавец-консультант в офис продаж "Билайн" (ст.м. Свиблово)': 50000},
#  {'Продавец-консультант YOTA': 30000},
#  {'Продавец-консультант': 27500.0},
#  {'Продавец-консультант': 50000.0},
#  {'Продавец-консультант': 25000},
#  {'Фармацевт': 25500.0},
#  {'Продавец-консультант': 25000},
#  {'Продавец-консультант': 26000.0},
#  {'Продавец-консультант': 20000},
#  {'Продавец-консультант': 37500.0},
#  {'Супервайзер по бурению нефтяных и газовых скважин (в городе Нефтеюганск)': 180000},
#  {'Супервайзер по бурению нефтяных и газовых скважин (в городе Нефтеюганск)': 180000},
#  {'Супервайзер по бурению нефтяных и газовых скважин (в городе Нефтеюганск)': 180000},
#  {'Фармацевт': 25500.0},
#  {'Продавец-кассир (ТЦ "Титан Арена")': 27000},
#  {'Продавец-кассир (ТЦ "РИО")': 30000},
#  {'Продавец-кассир (ТЦ "Лондон Молл")': 30000},
#  {'Продавец-кассир (ТЦ "Европолис")': 30000},
#  {'Разработчик БД': 75000.0},
#  {'Продавец-кассир (ТРК "Французский бульвар")': 30000},
#  {'Продавец-кассир (ТК "Фиолент")': 30000},
#  {'Продавец-кассир (ТК "Авеню") м. Проспект Просвещения': 30000},
#  {'Продавец товаров для детей': 30000},
#  {'Продавец (ТК "Балкания Nova")': 30000},
#  {'Продавец-консультант': 47500.0},
#  {'Преподаватель испанского/английского языков': 50000.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Фрезеровщик ЧПУ': 47500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Помощник юриста': 30000},
#  {'Прораб': 32500.0},
#  {'Помощник руководителя': 45000.0},
#  {'Швея/портной': 600},
#  {'Помощник мастера, оператор чесального оборудования': 800},
#  {'Ученик мастера по ремонту бытовой радиоэлектроники': 12500.0},
#  {'Помощник главного бухгалтера': 47500.0},
#  {'Уборщица/уборщик в фитнес-клуб': 30000.0},
#  {'Продавец-консультант мужских костюмов': 25000.0},
#  {'Хостес': 40000},
#  {'Полицейский водитель': 30000},
#  {'Полицейский - водитель': 30000},
#  {'Продавец-консультант мужских костюмов': 25000.0},
#  {'Системный администратор / Инженер технической поддержки отдела разработки': 55000.0},
#  {'Подсобный рабочий': 50000},
#  {'Повар холодного цеха': 40000},
#  {'Повар на завтраки': 37000},
#  {'Секретарь': 25000},
#  {'Продавец-консультант в ювелирный магазин TOUS': 25000},
#  {'Пекарь-кондитер': 32500.0},
#  {'Парикмахер-универсал/администратор': 180000.0},
#  {'Продавец-консультант в салон связи Евросеть': 55000},
#  {'Продавец в салон Евросеть': 55000},
#  {'Торговый представитель': 45000},
#  {'Электромонтер по обслуживанию электрооборудования (г. Новороссийск)': 25500.0},
#  {'Техник-электрик': 40000},
#  {'Продавец-консультант в салон связи': 55000},
#  {'Рабочий по обслуживанию и текущему ремонту 1 категории (г. Новороссийск)': 26550.0},
#  {'Продавец-консультант Евросеть': 55000},
#  {'Старший официант (отель в центре Санкт-Петербурга)': 28000},
#  {'Офис-менеджер/менеджер': 8000},
#  {'Офис-менеджер': 47500.0},
#  {'Электромеханик по холодильному оборудованию 1 категории (г. Новороссийск)': 33000.0},
#  {'Оператор call-центра': 20000},
#  {'Няня': 65000.0},
#  {'Продавец-консультант': 37500.0},
#  {'Электромеханик по холодильному оборудованию (г. Анапа)': 33000.0},
#  {'Продавец-консультант в салон связи "Евросеть" (м. Новогиреево)': 55000},
#  {'Начальник строительного участка': 80000.0},
#  {'Руководитель отдела корпоративных продаж': 105000.0},
#  {'Продавец-консультант в салон связи "Евросеть"': 55000},
#  {'Слесарь ремонтник/электро-механик': 50000.0},
#  {'Продавец Евросеть': 55000},
#  {'Мерчендайзер': 5000},
#  {'Продавец в салон связи "Евросеть"': 55000},
#  {'Социальный работник': 45000},
#  {'Руководитель отдела ресепшен и сервис': 50000},
#  {'Продавец-кассир в шоу-рум (ТРЦ Авиапарк)': 45000},
#  {'Продавец-консультант в салон связи': 55000},
#  {'Специалист экспортного отдела продаж': 1200},
#  {'Стажёр-программист (C#, .NET, ASP.NET MVC, ASP.NET Core, Xamarin, Unity)': 30000},
#  {'Техник по комплексному обслуживанию и ремонту зданий': 42250.0},
#  {'Слесарь по КИПИА': 55000},
#  {'Хостес': 37500.0},
#  {'Продавец-консультант в салон Евросеть': 55000},
#  {'Менеджер по товару (в ТК "Охта Молл")': 30000},
#  {'Продавец-стилист в шоу-рум (ТРЦ Коламбус)': 40000},
#  {'Техник по комплексному обслуживанию и ремонту зданий (г. Ногинск)': 42250.0},
#  {'Менеджер по работе с ключевыми клиентами': 115000.0},
#  {'Специалист по сопровождению клиентов': 40000},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 20000.0},
#  {'Продавец-консультант выходного дня': 15000},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 40000},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с клиентами': 90000},
#  {'Менеджер по работе с клиентами': 32500.0},
#  {'Продавец-консультант "Евросеть"': 55000},
#  {'Продавец Евросеть': 55000},
#  {'Системный аналитик': 80000},
#  {'Продавец в салон связи Евросеть': 55000},
#  {'Менеджер по продажам услуг': 10000.0},
#  {'Продавец в салон связи Евросеть (ночные смены)': 55000},
#  {'Продавец-консультант в салон связи': 55000},
#  {'Продавец-консультант в салон связи "Евросеть"': 55000},
#  {'Менеджер по продажам строительных материалов': 70000},
#  {'Продавец-консультант в салон связи "Евросеть"': 55000},
#  {'Продавец-консультант в "Евросеть"': 55000},
#  {'Менеджер по работе с клиентами': 40000.0},
#  {'Продавец в салон связи Евросеть': 55000},
#  {'Менеджер по продажам рекламы в спецпроектах и видеоблогах': 120000},
#  {'Менеджер по продажам электроизделий': 70000},
#  {'Продавец-кассир': 37500.0},
#  {'Менеджер по продажам мебели': 30000},
#  {'Менеджер по продажам мебели': 30000},
#  {'Специалист отдела закупок': 600},
#  {'Менеджер по продажам и обслуживанию / Продавец-консультант в салон "Ростелеком" (м. Адмиралтейская)': 40000.0},
#  {'Менеджер по продажам (без поиска)': 50000},
#  {'Менеджер по продажам': 62500.0},
#  {'Менеджер по продажам': 100000.0},
#  {'Продавец-консультант в салон связи "Евросеть"': 55000},
#  {'Продавец в салон Евросеть': 55000},
#  {'Продавец-консультант': 19000.0},
#  {'Оператор call-центра': 20000},
#  {'Продавец-консультант': 30000},
#  {'Менеджер по оптовым продажам инженерной сантехники': 105000.0},
#  {'Товаровед магазина "Магнит" (ст. Старотитаровская)': 28700.0},
#  {'Секретарь-референт': 35000.0},
#  {'Специалист службы поддержки кэшбэк-сервиса': 22500.0},
#  {'Менеджер по продажам (телефон) / оператор Колл - Центра': 60000.0},
#  {'Менеджер по продажам гидравлического оборудования': 90000.0},
#  {'Технический специалист': 45000.0},
#  {'Менеджер по промышленным продажам (Москва)': 90000.0},
#  {'Продавец магазина "Магнит-Косметик" (г. Темрюк)': 23050.0},
#  {'Менеджер по промышленным продажам': 80000.0},
#  {'Медсестра': 25000},
#  {'Менеджер по промышленным продажам (Екатеринбург)': 70000.0},
#  {'Продавец магазина "Магн\u200eит-Косметик" (ст. Тамань)': 25750.0},
#  {'Мастер текущего ремонта': 33600},
#  {'Менеджер по работе с клиентами (юридические лица)': 35000},
#  {'Продавец магазина "Магнит-Косметик" (п. Супсех)': 23600.0},
#  {'Сборщик- фасовщик (комплектовщик)': 40000.0},
#  {'Помощник маркетолога': 40000.0},
#  {'Младший специалист по маркетингу': 35000.0},
#  {'Маркетолог / рекламный агент / менеджер по продажам': 1500.0},
#  {'Продавец в магазин "Магнит-Косметик" (п. Сенной)': 19400.0},
#  {'Продавец магазина "Магнит-Косметик" (п. Кабардинка)': 27050.0},
#  {'Мастер ногтевого сервиса': 65000.0},
#  {'Курьер на личном автомобиле': 750.0},
#  {'Кредитный специалист (м. Старая Деревня)': 30000},
#  {'Менеджер по продажам': 62500.0},
#  {'Продавец магазина "Магнит-Косметик" (ст. Голубицкая)': 22450.0},
#  {'Кредитный специалист (м. Купчино)': 24000.0},
#  {'Кредитный специалист': 25000},
#  {'Кредитный специалист': 15000},
#  {'Учитель начальных классов': 40000},
#  {'Учитель истории и обществознания': 35000},
#  {'Старший продавец магазина "Магнит-Косметик" (п. Сенной)': 21600.0},
#  {'Менеджер по продажам (тендеры)': 35000},
#  {'Кредитный специалист': 26500.0},
#  {'Рекрутер/менеджер по подбору рабочих, бригад на стройку': 65000.0},
#  {'Менеджер по продажам (телемаркетинг)': 700.0},
#  {'Старший продавец магазина "Магнит-Косметик" (г. Новороссийск)': 27325.0},
#  {'Кредитный специалист': 23000.0},
#  {'Оператор-диспетчер / диспетчер скорой помощи': 55000.0},
#  {'Товаровед магазина "Магнит-Косметик" (г. Новороссийск)': 30900.0},
#  {'Коренщица/коренщик': 36000},
#  {'Консультант 1С/Аналитик 1с': 137500.0},
#  {'Супервайзер торговых представителей': 45000.0},
#  {'Кладовщик-комплектовщик': 25000.0},
#  {'Упаковщик': 109000.0},
#  {'Финансовый директор': 130000},
#  {'Охранник': 18000},
#  {'Юрисконсульт': 80000.0},
#  {'Кассир (г. Красноармейск)': 33500.0},
#  {'Каменщик': 1300},
#  {'Фельдшер (Екатеринбург)': 27000},
#  {'Инженер-эколог': 30000.0},
#  {'Медицинская сестра участковая (Екатеринбург)': 21825.0},
#  {'Медицинская сестра участковая': 21825.0},
#  {'Инженер технической поддержки': 32500.0},
#  {'Инженер по ремонту холодильного оборудования (г. Новороссийск)': 33000.0},
#  {'Программист': 22500.0},
#  {'Инженер по автоматизации тестирования (Developer in QA)': 130000.0},
#  {'Инженер отдела мониторинга технологических процессов': 25000},
#  {'Инженер ПТО в сфере строительства АСУДД и светофорных объектов': 50000},
#  {'Инженер ПТО': 55000.0},
#  {'Инженер': 25000},
#  {'Заместитель директора розницы': 80000},
#  {'Замерщик мебели/ менеджер по продажам на выезде': 110000.0},
#  {'Директор филиала транспортной компании (сборные грузоперевозки)': 65000.0},
#  {'Директор типографии': 80000.0},
#  {'Экономист (Екатеринбург)': 25500.0},
#  {'Дизайнер-консультант/Менеджер по продажам (кухонная мебель, ТЦ Красный Кит)': 70000},
#  {'Дизайнер-консультант / Менеджер по продажам без опыта (кухонная мебель, ТЦ Красный Кит)': 60000},
#  {'Дизайнер интерьеров': 30000.0},
#  {'Инструктор-кинолог отдела охраны': 20000},
#  {'Младший инспектор отдела охраны': 20000},
#  {'Продавец-консультант выходного дня': 14000.0},
#  {'Портной': 800},
#  {'Помощник автомаляра/ слесарь': 15000},
#  {'Инженер-конструктор (машиностроение)': 80000},
#  {'Главный бухгалтер': 45000.0},
#  {'Консультант-разработчик Siebel CRM': 100000},
#  {'Врач-эксперт направления медико-экономической экспертизы (МЭЭ)': 90000.0},
#  {'Региональный менеджер по работе с ключевыми клиентами': 82500.0},
#  {'Менеджер по работе с ключевыми клиентами': 82500.0},
#  {'Преподаватель английского языка': 40000.0},
#  {'Пекарь': 700},
#  {'Врач-терапевт (участковый), Екатеринбург': 38000},
#  {'Программист 1С': 70000.0},
#  {'Менеджер по продажам - консультант/секретарь': 40000},
#  {'Менеджер по продажам': 125000.0},
#  {'Секретарь-делопроизводитель': 80000.0},
#  {'Врач-кардиолог (Екатеринбург)': 34500.0},
#  {'Мерчендайзер-консультант на электроинструмент мирового бренда': 21693},
#  {'Специалист направления мотивации и оплаты труда/C&B': 70000},
#  {'Промоутер-консультант (бытовая техника Midea)': 65000},
#  {'Медиа-байер / специалист по закупке трафика': 50000.0},
#  {'Продавец-консультант (техника GARDENA)': 20000},
#  {'Продавец-консультант (Gardena)': 35000},
#  {'Разработчик C++': 70000},
#  {'Продавец-кассир магазина обуви': 30000.0},
#  {'Помощник руководителя/менеджер': 10000},
#  {'Менеджер IT-проектов': 90000.0},
#  {'Продавец-консультант в ТЦ': 30000.0},
#  {'Менеджер по работе со студентами': 46000.0},
#  {'Маркетолог (блогер)': 35000},
#  {'Техник-универсал': 40000},
#  {'Разработчик C++': 90000},
#  {'Менеджер по корпоративным продажам': 60000.0},
#  {'Менеджер по работе с корпоративными клиентами': 61000.0},
#  {'Торговый представитель': 32000.0},
#  {'Монтажник': 40000.0},
#  {'Руководитель отдела аренды': 60000},
#  {'Оператор печатного оборудования': 20000.0},
#  {'Секретарь на ресепшен': 24000.0},
#  {'Дизайнер': 30000.0},
#  {'Менеджер по работе с клиентами (в сервисный центр)': 21500.0},
#  {'Менеджер по работе с клиентами (производственное направление)': 87500.0},
#  {'Менеджер по продажам': 80000},
#  {'Инженер-конструктор': 40000.0},
#  {'Разработчик C++': 100000},
#  {'Помощник установщика': 37500.0},
#  {'Водитель в отель': 30000},
#  {'Водитель КаМаз ФАУН мусоровоз': 45000},
#  {'Водитель': 35000.0},
#  {'Менеджер по продажам в интернет-магазин (секс шоп)': 42500.0},
#  {'Водитель такси': 110000.0},
#  {'Разработчик C++': 115000},
#  {'Вечерний Консультант 1С': 15000.0},
#  {'Ведущий юрист проектной организации': 85000.0},
#  {'Врач-гинеколог': 115000.0},
#  {'Ведущий специалист Информационного центра': 40000.0},
#  {'Заместитель главного бухгалтера': 60000},
#  {'Врач-онколог': 30000},
#  {'Врач-онколог': 30000},
#  {'Врач-онколог': 30000},
#  {'Врач-онколог': 30000},
#  {'Врач-онколог': 30000},
#  {'Врач-онколог': 30000},
#  {'Врач-онколог': 30000},
#  {'Старший бухгалтер (взаиморасчеты с зарубежными поставщиками)': 65000},
#  {'Ведущий архитектор': 70000.0},
#  {'Менеджер по продажам новостроек': 192500.0},
#  {'Фотограф': 30000},
#  {'Фармацевт-провизор': 30000.0},
#  {'Ветеринарный врач': 16000.0},
#  {'Менеджер отдела продаж по работе с ключевыми клиентами': 600000.0},
#  {'Охранник': 40000},
#  {'Менеджер отдела продаж': 125000.0},
#  {'Охранник': 45000},
#  {'Вечерний специалист по работе с клиентами': 25000},
#  {'Менеджер отдела продаж': 120000},
#  {'Менеджер переводчик бюро переводов': 35000.0},
#  {'Управляющий Converse': 65000.0},
#  {'Вечерний менеджер': 25000},
#  {'Закройщик': 600},
#  {'Водитель-экспедитор': 52000},
#  {'Менеджер в отдел телефонных продаж': 20000},
#  {'Комлектовщик  (Крекшино/Бекасово)': 52000},
#  {'Бариста/кассир': 33000.0},
#  {'Менеджер по продажам': 30000},
#  {'Торговый представитель': 45000.0},
#  {'Дизайнер-иллюстратор': 37500.0},
#  {'Менеджер визового отдела': 30000},
#  {'Менеджер по работе с клиентами': 45000.0},
#  {'Менеджер по работе с клиентами': 85000.0},
#  {'Сварщик рекламных конструкций': 50000.0},
#  {'Водитель-экспедитор': 42500.0},
#  {'Менеджер по туризму': 115000.0},
#  {'Заместитель начальника отдела бухгалтерского учета в аудиторскую фирму': 80000},
#  {'Администратор региона': 20500.0},
#  {'Повар на хачапури': 40000},
#  {'Секретарь': 25000},
#  {'Продавец-кассир': 35000.0},
#  {'Сборщик мебели': 70000},
#  {'Промоутер': 10000},
#  {'Медицинский представитель': 48000},
#  {'Менеджер по туризму': 1850.0},
#  {'Менеджер по продажам (спорт/фитнес клуб)': 50000.0},
#  {'Оператор фасовочной линии': 20000},
#  {'Помощник воспитателя в частный детский сад': 19000},
#  {'Продавец-консультант': 29500.0},
#  {'Комплектовщик': 22000},
#  {'Администратор в Салон Красоты': 27500.0},
#  {'Водитель погрузчика': 30000},
#  {'Водитель погрузчика': 35000},
#  {'Руководитель отдела продаж': 85000.0},
#  {'Менеджер по работе с клиентами': 25000},
#  {'Менеджер по продажам': 55000.0},
#  {'Менеджер кафе': 35000},
#  {'Официант': 20000},
#  {'Менеджер по продажам Департамента ипотечного кредитования': 50000.0},
#  {'Специалист по бронированию': 30000.0},
#  {'Слесарь аварийно-восстановительных работ': 40000},
#  {'RUSLAN FAKHRUTDINOV': 40000},
#  {'Врач косметолог (дерматокосметолог)': 70000.0},
#  {'Юрист': 80000.0},
#  {'Консультант по работе с клиентами': 25000},
#  {'Торговый представитель': 35000},
#  {'Пикчер': 100000},
#  {'Менеджер по продажам выставочного зала': 30000},
#  {'Lead Developer': 3300.0},
#  {'Специалист по охране труда и технике безопасности': 60000},
#  {'SMM-специалист': 40000.0},
#  {'Офис-менеджер': 18500.0},
#  {'Водитель Газели': 20000},
#  {'Менеджер по персоналу (Чемпионат мира по футболу 2018)': 40000.0},
#  {'Водитель такси': 105000.0},
#  {'Оператор call-центра на Чемпионат мира по футболу': 30000},
#  {'Бухгалтер': 30000},
#  {'Менеджер по продажам': 185000.0},
#  {'Ведущий специалист ОМТС (44-ФЗ)': 60000},
#  {'Ведущий специалист отдела юридического сопровождения закупочных процедур (44-ФЗ)': 70000},
#  {'Выпускающий редактор журнала Банзай': 30000.0},
#  {'Ведущий специалист по закупкам IT оборудования': 90000},
#  {'Косметолог-эстетист': 35000.0}]

# %%
med=[]
sred=[]
for myi in range(len(mid)-1):
     for k1, v1 in mid[len(mid)-1-myi].items():
            for k2, v2 in mid[len(mid)-2-myi].items():
                if k1==k2: 
                    sred.append(v1)
                else:
                    sred.append(v1)
                    if (len(sred) % 2) != 0:
                        el = {k1:sred[(len(sred)//2)]}
                    else:
                        el = {k1:(sred[len(sred)//2]+sred[(len(sred)//2)-1])/2}
                    med.append(el)
                    l=len(sred)
                    for k in range(l):
                        sred.pop(l-1-k)
med
# Out:
# [{'Косметолог-эстетист': 35000.0},
#  {'Ведущий специалист по закупкам IT оборудования': 90000},
#  {'Выпускающий редактор журнала Банзай': 30000.0},
#  {'Ведущий специалист отдела юридического сопровождения закупочных процедур (44-ФЗ)': 70000},
#  {'Ведущий специалист ОМТС (44-ФЗ)': 60000},
#  {'Менеджер по продажам': 185000.0},
#  {'Бухгалтер': 30000},
#  {'Оператор call-центра на Чемпионат мира по футболу': 30000},
#  {'Водитель такси': 105000.0},
#  {'Менеджер по персоналу (Чемпионат мира по футболу 2018)': 40000.0},
#  {'Водитель Газели': 20000},
#  {'Офис-менеджер': 18500.0},
#  {'SMM-специалист': 40000.0},
#  {'Специалист по охране труда и технике безопасности': 60000},
#  {'Lead Developer': 3300.0},
#  {'Менеджер по продажам выставочного зала': 30000},
#  {'Пикчер': 100000},
#  {'Торговый представитель': 35000},
#  {'Консультант по работе с клиентами': 25000},
#  {'Юрист': 80000.0},
#  {'Врач косметолог (дерматокосметолог)': 70000.0},
#  {'RUSLAN FAKHRUTDINOV': 40000},
#  {'Слесарь аварийно-восстановительных работ': 40000},
#  {'Специалист по бронированию': 30000.0},
#  {'Менеджер по продажам Департамента ипотечного кредитования': 50000.0},
#  {'Официант': 20000},
#  {'Менеджер кафе': 35000},
#  {'Менеджер по продажам': 55000.0},
#  {'Менеджер по работе с клиентами': 25000},
#  {'Руководитель отдела продаж': 85000.0},
#  {'Водитель погрузчика': 32500.0},
#  {'Администратор в Салон Красоты': 27500.0},
#  {'Комплектовщик': 22000},
#  {'Продавец-консультант': 29500.0},
#  {'Помощник воспитателя в частный детский сад': 19000},
#  {'Оператор фасовочной линии': 20000},
#  {'Менеджер по продажам (спорт/фитнес клуб)': 50000.0},
#  {'Менеджер по туризму': 1850.0},
#  {'Медицинский представитель': 48000},
#  {'Промоутер': 10000},
#  {'Сборщик мебели': 70000},
#  {'Продавец-кассир': 35000.0},
#  {'Секретарь': 25000},
#  {'Повар на хачапури': 40000},
#  {'Администратор региона': 20500.0},
#  {'Заместитель начальника отдела бухгалтерского учета в аудиторскую фирму': 80000},
#  {'Менеджер по туризму': 115000.0},
#  {'Водитель-экспедитор': 42500.0},
#  {'Сварщик рекламных конструкций': 50000.0},
#  {'Менеджер по работе с клиентами': 65000.0},
#  {'Менеджер визового отдела': 30000},
#  {'Дизайнер-иллюстратор': 37500.0},
#  {'Торговый представитель': 45000.0},
#  {'Менеджер по продажам': 30000},
#  {'Бариста/кассир': 33000.0},
#  {'Комлектовщик  (Крекшино/Бекасово)': 52000},
#  {'Менеджер в отдел телефонных продаж': 20000},
#  {'Водитель-экспедитор': 52000},
#  {'Закройщик': 600},
#  {'Вечерний менеджер': 25000},
#  {'Управляющий Converse': 65000.0},
#  {'Менеджер переводчик бюро переводов': 35000.0},
#  {'Менеджер отдела продаж': 120000},
#  {'Вечерний специалист по работе с клиентами': 25000},
#  {'Охранник': 45000},
#  {'Менеджер отдела продаж': 125000.0},
#  {'Охранник': 40000},
#  {'Менеджер отдела продаж по работе с ключевыми клиентами': 600000.0},
#  {'Ветеринарный врач': 16000.0},
#  {'Фармацевт-провизор': 30000.0},
#  {'Фотограф': 30000},
#  {'Менеджер по продажам новостроек': 192500.0},
#  {'Ведущий архитектор': 70000.0},
#  {'Старший бухгалтер (взаиморасчеты с зарубежными поставщиками)': 65000},
#  {'Врач-онколог': 30000},
#  {'Заместитель главного бухгалтера': 60000},
#  {'Ведущий специалист Информационного центра': 40000.0},
#  {'Врач-гинеколог': 115000.0},
#  {'Ведущий юрист проектной организации': 85000.0},
#  {'Вечерний Консультант 1С': 15000.0},
#  {'Разработчик C++': 115000},
#  {'Водитель такси': 110000.0},
#  {'Менеджер по продажам в интернет-магазин (секс шоп)': 42500.0},
#  {'Водитель': 35000.0},
#  {'Водитель КаМаз ФАУН мусоровоз': 45000},
#  {'Водитель в отель': 30000},
#  {'Помощник установщика': 37500.0},
#  {'Разработчик C++': 100000},
#  {'Инженер-конструктор': 40000.0},
#  {'Менеджер по продажам': 80000},
#  {'Менеджер по работе с клиентами (производственное направление)': 87500.0},
#  {'Менеджер по работе с клиентами (в сервисный центр)': 21500.0},
#  {'Дизайнер': 30000.0},
#  {'Секретарь на ресепшен': 24000.0},
#  {'Оператор печатного оборудования': 20000.0},
#  {'Руководитель отдела аренды': 60000},
#  {'Монтажник': 40000.0},
#  {'Торговый представитель': 32000.0},
#  {'Менеджер по работе с корпоративными клиентами': 61000.0},
#  {'Менеджер по корпоративным продажам': 60000.0},
#  {'Разработчик C++': 90000},
#  {'Техник-универсал': 40000},
#  {'Маркетолог (блогер)': 35000},
#  {'Менеджер по работе со студентами': 46000.0},
#  {'Продавец-консультант в ТЦ': 30000.0},
#  {'Менеджер IT-проектов': 90000.0},
#  {'Помощник руководителя/менеджер': 10000},
#  {'Продавец-кассир магазина обуви': 30000.0},
#  {'Разработчик C++': 70000},
#  {'Продавец-консультант (Gardena)': 35000},
#  {'Продавец-консультант (техника GARDENA)': 20000},
#  {'Медиа-байер / специалист по закупке трафика': 50000.0},
#  {'Промоутер-консультант (бытовая техника Midea)': 65000},
#  {'Специалист направления мотивации и оплаты труда/C&B': 70000},
#  {'Мерчендайзер-консультант на электроинструмент мирового бренда': 21693},
#  {'Врач-кардиолог (Екатеринбург)': 34500.0},
#  {'Секретарь-делопроизводитель': 80000.0},
#  {'Менеджер по продажам': 125000.0},
#  {'Менеджер по продажам - консультант/секретарь': 40000},
#  {'Программист 1С': 70000.0},
#  {'Врач-терапевт (участковый), Екатеринбург': 38000},
#  {'Пекарь': 700},
#  {'Преподаватель английского языка': 40000.0},
#  {'Менеджер по работе с ключевыми клиентами': 82500.0},
#  {'Региональный менеджер по работе с ключевыми клиентами': 82500.0},
#  {'Врач-эксперт направления медико-экономической экспертизы (МЭЭ)': 90000.0},
#  {'Консультант-разработчик Siebel CRM': 100000},
#  {'Главный бухгалтер': 45000.0},
#  {'Инженер-конструктор (машиностроение)': 80000},
#  {'Помощник автомаляра/ слесарь': 15000},
#  {'Портной': 800},
#  {'Продавец-консультант выходного дня': 14000.0},
#  {'Младший инспектор отдела охраны': 20000},
#  {'Инструктор-кинолог отдела охраны': 20000},
#  {'Дизайнер интерьеров': 30000.0},
#  {'Дизайнер-консультант / Менеджер по продажам без опыта (кухонная мебель, ТЦ Красный Кит)': 60000},
#  {'Дизайнер-консультант/Менеджер по продажам (кухонная мебель, ТЦ Красный Кит)': 70000},
#  {'Экономист (Екатеринбург)': 25500.0},
#  {'Директор типографии': 80000.0},
#  {'Директор филиала транспортной компании (сборные грузоперевозки)': 65000.0},
#  {'Замерщик мебели/ менеджер по продажам на выезде': 110000.0},
#  {'Заместитель директора розницы': 80000},
#  {'Инженер': 25000},
#  {'Инженер ПТО': 55000.0},
#  {'Инженер ПТО в сфере строительства АСУДД и светофорных объектов': 50000},
#  {'Инженер отдела мониторинга технологических процессов': 25000},
#  {'Инженер по автоматизации тестирования (Developer in QA)': 130000.0},
#  {'Программист': 22500.0},
#  {'Инженер по ремонту холодильного оборудования (г. Новороссийск)': 33000.0},
#  {'Инженер технической поддержки': 32500.0},
#  {'Медицинская сестра участковая': 21825.0},
#  {'Медицинская сестра участковая (Екатеринбург)': 21825.0},
#  {'Инженер-эколог': 30000.0},
#  {'Фельдшер (Екатеринбург)': 27000},
#  {'Каменщик': 1300},
#  {'Кассир (г. Красноармейск)': 33500.0},
#  {'Юрисконсульт': 80000.0},
#  {'Охранник': 18000},
#  {'Финансовый директор': 130000},
#  {'Упаковщик': 109000.0},
#  {'Кладовщик-комплектовщик': 25000.0},
#  {'Супервайзер торговых представителей': 45000.0},
#  {'Консультант 1С/Аналитик 1с': 137500.0},
#  {'Коренщица/коренщик': 36000},
#  {'Товаровед магазина "Магнит-Косметик" (г. Новороссийск)': 30900.0},
#  {'Оператор-диспетчер / диспетчер скорой помощи': 55000.0},
#  {'Кредитный специалист': 23000.0},
#  {'Старший продавец магазина "Магнит-Косметик" (г. Новороссийск)': 27325.0},
#  {'Менеджер по продажам (телемаркетинг)': 700.0},
#  {'Рекрутер/менеджер по подбору рабочих, бригад на стройку': 65000.0},
#  {'Кредитный специалист': 26500.0},
#  {'Менеджер по продажам (тендеры)': 35000},
#  {'Старший продавец магазина "Магнит-Косметик" (п. Сенной)': 21600.0},
#  {'Учитель истории и обществознания': 35000},
#  {'Учитель начальных классов': 40000},
#  {'Кредитный специалист': 20000.0},
#  {'Кредитный специалист (м. Купчино)': 24000.0},
#  {'Продавец магазина "Магнит-Косметик" (ст. Голубицкая)': 22450.0},
#  {'Менеджер по продажам': 62500.0},
#  {'Кредитный специалист (м. Старая Деревня)': 30000},
#  {'Курьер на личном автомобиле': 750.0},
#  {'Мастер ногтевого сервиса': 65000.0},
#  {'Продавец магазина "Магнит-Косметик" (п. Кабардинка)': 27050.0},
#  {'Продавец в магазин "Магнит-Косметик" (п. Сенной)': 19400.0},
#  {'Маркетолог / рекламный агент / менеджер по продажам': 1500.0},
#  {'Младший специалист по маркетингу': 35000.0},
#  {'Помощник маркетолога': 40000.0},
#  {'Сборщик- фасовщик (комплектовщик)': 40000.0},
#  {'Продавец магазина "Магнит-Косметик" (п. Супсех)': 23600.0},
#  {'Менеджер по работе с клиентами (юридические лица)': 35000},
#  {'Мастер текущего ремонта': 33600},
#  {'Продавец магазина "Магн\u200eит-Косметик" (ст. Тамань)': 25750.0},
#  {'Менеджер по промышленным продажам (Екатеринбург)': 70000.0},
#  {'Медсестра': 25000},
#  {'Менеджер по промышленным продажам': 80000.0},
#  {'Продавец магазина "Магнит-Косметик" (г. Темрюк)': 23050.0},
#  {'Менеджер по промышленным продажам (Москва)': 90000.0},
#  {'Технический специалист': 45000.0},
#  {'Менеджер по продажам гидравлического оборудования': 90000.0},
#  {'Менеджер по продажам (телефон) / оператор Колл - Центра': 60000.0},
#  {'Специалист службы поддержки кэшбэк-сервиса': 22500.0},
#  {'Секретарь-референт': 35000.0},
#  {'Товаровед магазина "Магнит" (ст. Старотитаровская)': 28700.0},
#  {'Менеджер по оптовым продажам инженерной сантехники': 105000.0},
#  {'Продавец-консультант': 30000},
#  {'Оператор call-центра': 20000},
#  {'Продавец-консультант': 19000.0},
#  {'Продавец в салон Евросеть': 55000},
#  {'Продавец-консультант в салон связи "Евросеть"': 55000},
#  {'Менеджер по продажам': 81250.0},
#  {'Менеджер по продажам (без поиска)': 50000},
#  {'Менеджер по продажам и обслуживанию / Продавец-консультант в салон "Ростелеком" (м. Адмиралтейская)': 40000.0},
#  {'Специалист отдела закупок': 600},
#  {'Менеджер по продажам мебели': 30000.0},
#  {'Продавец-кассир': 37500.0},
#  {'Менеджер по продажам электроизделий': 70000},
#  {'Менеджер по продажам рекламы в спецпроектах и видеоблогах': 120000},
#  {'Продавец в салон связи Евросеть': 55000},
#  {'Менеджер по работе с клиентами': 40000.0},
#  {'Продавец-консультант в "Евросеть"': 55000},
#  {'Продавец-консультант в салон связи "Евросеть"': 55000},
#  {'Менеджер по продажам строительных материалов': 70000},
#  {'Продавец-консультант в салон связи "Евросеть"': 55000},
#  {'Продавец-консультант в салон связи': 55000},
#  {'Продавец в салон связи Евросеть (ночные смены)': 55000},
#  {'Менеджер по продажам услуг': 10000.0},
#  {'Продавец в салон связи Евросеть': 55000},
#  {'Системный аналитик': 80000},
#  {'Продавец Евросеть': 55000},
#  {'Продавец-консультант "Евросеть"': 55000},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Продавец-консультант выходного дня': 15000},
#  {'Менеджер по работе с клиентами': 21250.0},
#  {'Специалист по сопровождению клиентов': 40000},
#  {'Менеджер по работе с ключевыми клиентами': 115000.0},
#  {'Техник по комплексному обслуживанию и ремонту зданий (г. Ногинск)': 42250.0},
#  {'Продавец-стилист в шоу-рум (ТРЦ Коламбус)': 40000},
#  {'Менеджер по товару (в ТК "Охта Молл")': 30000},
#  {'Продавец-консультант в салон Евросеть': 55000},
#  {'Хостес': 37500.0},
#  {'Слесарь по КИПИА': 55000},
#  {'Техник по комплексному обслуживанию и ремонту зданий': 42250.0},
#  {'Стажёр-программист (C#, .NET, ASP.NET MVC, ASP.NET Core, Xamarin, Unity)': 30000},
#  {'Специалист экспортного отдела продаж': 1200},
#  {'Продавец-консультант в салон связи': 55000},
#  {'Продавец-кассир в шоу-рум (ТРЦ Авиапарк)': 45000},
#  {'Руководитель отдела ресепшен и сервис': 50000},
#  {'Социальный работник': 45000},
#  {'Продавец в салон связи "Евросеть"': 55000},
#  {'Мерчендайзер': 5000},
#  {'Продавец Евросеть': 55000},
#  {'Слесарь ремонтник/электро-механик': 50000.0},
#  {'Продавец-консультант в салон связи "Евросеть"': 55000},
#  {'Руководитель отдела корпоративных продаж': 105000.0},
#  {'Начальник строительного участка': 80000.0},
#  {'Продавец-консультант в салон связи "Евросеть" (м. Новогиреево)': 55000},
#  {'Электромеханик по холодильному оборудованию (г. Анапа)': 33000.0},
#  {'Продавец-консультант': 37500.0},
#  {'Няня': 65000.0},
#  {'Оператор call-центра': 20000},
#  {'Электромеханик по холодильному оборудованию 1 категории (г. Новороссийск)': 33000.0},
#  {'Офис-менеджер': 47500.0},
#  {'Офис-менеджер/менеджер': 8000},
#  {'Старший официант (отель в центре Санкт-Петербурга)': 28000},
#  {'Продавец-консультант Евросеть': 55000},
#  {'Рабочий по обслуживанию и текущему ремонту 1 категории (г. Новороссийск)': 26550.0},
#  {'Продавец-консультант в салон связи': 55000},
#  {'Техник-электрик': 40000},
#  {'Электромонтер по обслуживанию электрооборудования (г. Новороссийск)': 25500.0},
#  {'Торговый представитель': 45000},
#  {'Продавец в салон Евросеть': 55000},
#  {'Продавец-консультант в салон связи Евросеть': 55000},
#  {'Парикмахер-универсал/администратор': 180000.0},
#  {'Пекарь-кондитер': 32500.0},
#  {'Продавец-консультант в ювелирный магазин TOUS': 25000},
#  {'Секретарь': 25000},
#  {'Повар на завтраки': 37000},
#  {'Повар холодного цеха': 40000},
#  {'Подсобный рабочий': 50000},
#  {'Системный администратор / Инженер технической поддержки отдела разработки': 55000.0},
#  {'Продавец-консультант мужских костюмов': 25000.0},
#  {'Полицейский - водитель': 30000},
#  {'Полицейский водитель': 30000},
#  {'Хостес': 40000},
#  {'Продавец-консультант мужских костюмов': 25000.0},
#  {'Уборщица/уборщик в фитнес-клуб': 30000.0},
#  {'Помощник главного бухгалтера': 47500.0},
#  {'Ученик мастера по ремонту бытовой радиоэлектроники': 12500.0},
#  {'Помощник мастера, оператор чесального оборудования': 800},
#  {'Швея/портной': 600},
#  {'Помощник руководителя': 45000.0},
#  {'Прораб': 32500.0},
#  {'Помощник юриста': 30000},
#  {'Преподаватель английского языка': 27500.0},
#  {'Фрезеровщик ЧПУ': 47500.0},
#  {'Преподаватель английского языка': 27500.0},
#  {'Преподаватель испанского/английского языков': 50000.0},
#  {'Продавец-консультант': 47500.0},
#  {'Продавец (ТК "Балкания Nova")': 30000},
#  {'Продавец товаров для детей': 30000},
#  {'Продавец-кассир (ТК "Авеню") м. Проспект Просвещения': 30000},
#  {'Продавец-кассир (ТК "Фиолент")': 30000},
#  {'Продавец-кассир (ТРК "Французский бульвар")': 30000},
#  {'Разработчик БД': 75000.0},
#  {'Продавец-кассир (ТЦ "Европолис")': 30000},
#  {'Продавец-кассир (ТЦ "Лондон Молл")': 30000},
#  {'Продавец-кассир (ТЦ "РИО")': 30000},
#  {'Продавец-кассир (ТЦ "Титан Арена")': 27000},
#  {'Фармацевт': 25500.0},
#  {'Супервайзер по бурению нефтяных и газовых скважин (в городе Нефтеюганск)': 180000},
#  {'Продавец-консультант': 23000.0},
#  {'Фармацевт': 25500.0},
#  {'Продавец-консультант': 50000.0},
#  {'Продавец-консультант YOTA': 30000},
#  {'Продавец-консультант в офис продаж "Билайн" (ст.м. Свиблово)': 50000},
#  {'Специалист технической поддержки (1 уровень)': 55000},
#  {'Специалист управления данными (в IT-компанию)': 60000},
#  {'Специалист управления данными': 30000},
#  {'Разработчик С++': 60000.0},
#  {'Специалист по лазерной эпиляции': 80000},
#  {'Промоутер-распространитель': 15500.0},
#  {'Разнорабочий в столярную мастерскую': 400.0},
#  {'Региональный менеджер по продажам': 35000.0},
#  {'Региональный представитель портала недвижимости': 55000.0},
#  {'Юрист': 35000.0},
#  {'Руководитель группы гидрогеологов (Отдел гидродинамического моделирования)': 35000},
#  {'Руководитель отдела по работе с партнерами': 72500.0},
#  {'Руководитель отдела продаж': 117500.0},
#  {'Руководитель проекта (дорожное строительство)': 100000},
#  {'Сварщик НАКС': 100000},
#  {'Секретарь-делопроизводитель': 32500.0},
#  {'Слесарь механосборочных работ': 57500.0},
#  {'Специалист по закупкам и снабжению': 70000.0},
#  {'Слесарь-ремонтник металлургического оборудования': 26500.0},
#  {'Слесарь механосборочных работ': 57500.0},
#  {'Сомелье': 40000.0},
#  {'Электросварщик ручной сварки (6 разряд)': 29300.0},
#  {'Специалист лазерной эпиляции': 24000},
#  {'Специалист отдела информационного обслуживания (ВТБ)': 20000},
#  {'Специалист отдела продаж ипотечных кредитов (старший/главный)': 45000.0},
#  {'Специалист планово-экономического отдела': 70000},
#  {'Специалист по администрированию и ведению проектов': 40000.0},
#  {'Специалист по кредитованию': 15000},
#  {'Специалист по продажам': 687.5},
#  {'Специалист по работе с недвижимостью': 35000},
#  {'Специалист технической поддержки': 26500.0},
#  {'Старший рекрутер, hr-специалист': 50000.0},
#  {'Старший специалист/Ведущий специалист отдела продаж ипотечных продуктов': 30000},
#  {'Старший/ведущий специалист отдела продаж ипотечных продуктов': 35000},
#  {'Столяр-станочник / Столяр-мебельщик': 60000},
#  {'Су-шеф (повар-универсал)': 30000.0},
#  {'Территориальный торговый представитель (Ярославль, Кострома и области)': 40000},
#  {'Товаровед-оценщик в ломбард': 50000.0},
#  {'Тренер-технолог/Технолог-колорист': 80000},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Финансист-экономист': 32500.0},
#  {'Шлифовщик': 40000.0},
#  {'Электромонтажник': 65000.0},
#  {'Электросварщик на автоматических и полуавтоматических машинах': 57500.0},
#  {'Юрисконсульт Отдела правового сопровождения кредитования и розничного бизнеса': 65000.0},
#  {'Юрист с функциями администратора': 32500.0},
#  {'Юрисконсульт (Россошь)': 24000},
#  {'Электромонтажник': 47500.0},
#  {'Экспедитор (Водитель)': 700.0},
#  {'Швея-портной в магазин ткани': 15000},
#  {'Фармацевт-провизор': 20000.0},
#  {'Удаленный оператор на телефоне в московскую рекламную компанию.': 65.0},
#  {'Торговый представитель': 87500.0},
#  {'Технический специалист': 35000.0},
#  {'Территориальный менеджер (салоны Билайн)': 70000.0},
#  {'Су-шеф': 60000.0},
#  {'Старший/ведущий специалист отдела продаж ипотечных продуктов': 35000},
#  {'Старший юрисконсульт Отдела судебного взыскания (направление – судебное взыскание)': 68500.0},
#  {'Старший специалист группы Процессинга': 25000},
#  {'Старший бухгалтер-экономист': 122500.0},
#  {'Специалист по таргетированной рекламе': 100000},
#  {'Специалист по работе с клиентами': 700.0},
#  {'Специалист по продажам': 1000000},
#  {'Специалист по подготовке тендерной документации (ФЗ 223, ФЗ 44)': 70000.0},
#  {'Специалист по администрированию и ведению проектов': 40000.0},
#  {'Специалист отдела снабжения': 85000.0},
#  {'Специалист отдела по расследованию мошеннических и спорных операций': 27000},
#  {'Специалист линии поддержки англоговорящих клиентов': 32000.0},
#  {'Специалист контакт-центра (Банк ВТБ)': 20000},
#  {'Сотрудник Росгвардии': 50000.0},
#  {'Слесарь механосборочных работ': 45000},
#  {'Сервис-консультант СК Режим (проспект Героев, проспект Молодежный, ул. Щербакова)': 36000},
#  {'Сварщик, помощник сварщика': 27500.0},
#  {'С# - разработчик': 125000.0},
#  {'Руководитель отдела продаж отопительного оборудования': 70000},
#  {'Руководитель отдела продаж': 130000.0},
#  {'Руководитель группы гидрогеологов отдела гидрогеологии': 35000},
#  {'Риэлтор на входящие заявки': 45000.0},
#  {'Резчик / оператор бобинорезательного оборудования в типографию': 40000},
#  {'Региональный представитель портала недвижимости': 55000.0},
#  {'Разработчик React Native': 150000},
#  {'Промоутер-распространитель': 15500.0},
#  {'Производитель работ ( монолитные работы)': 65000.0},
#  {'Продавец-флорист': 9750.0},
#  {'Продавец-консультант/кассир-продавец': 15000},
#  {'Продавец-консультант электрики': 45000},
#  {'Продавец-консультант детского магазина': 75000.0},
#  {'Продавец-консультант в отдел косметики': 17500.0},
#  {'Продавец-консультант в магазин нижнего белья': 25000.0},
#  {'Продавец-консультант "Forest-Home" (Апраксин переулок)': 37500.0},
#  {'Продавец-консультант': 35000.0},
#  {'Продавец-кассир товаров для детей (в ТК "Мега Дыбенко")': 30000},
#  {'Продавец-кассир (ТЦ "Южный")': 27000},
#  {'Продавец-кассир (ТЦ "Сити молл")': 30000},
#  {'Продавец-кассир (ТЦ "Макси")': 26000},
#  {'Продавец-кассир (ТЦ "Карусель" Савушкина 116)': 30000},
#  {'Продавец-кассир (ТЦ "Апельсин")': 24000},
#  {'Продавец-кассир (ТЦ "Акваполис")': 22000},
#  {'Продавец-кассир (ТРК "Мега ПАРНАС")': 30000},
#  {'Продавец-кассир (ТК "Континент Бухарестская")': 30000},
#  {'Продавец-кассир': 32500.0},
#  {'Продавец консультант': 27500.0},
#  {'Программист С++': 70000},
#  {'Программист C/С++': 70000.0},
#  {'Преподаватель английского языка': 22000.0},
#  {'Помощник юриста': 13500.0},
#  {'Помощник руководителя отдела по подбору персонала': 65000},
#  {'Помощник менеджера по продажам': 9000.0},
#  {'Помощник мастера по наращиванию волос': 40000},
#  {'Помощник коммерческого директора': 27000.0},
#  {'Помощник бухгалтера по документам': 13500.0},
#  {'Помощник администратора сайта': 56000.0},
#  {'Помощник SEO-специалиста / Младший SEO-оптимизатор / Интернет-маркетолог': 30000.0},
#  {'Полиц\u200eейск\u200eий (Москва)': 45000},
#  {'Полицейский - водитель': 30000.0},
#  {'Повар-кондитер': 40000},
#  {'Повар универсал': 45000.0},
#  {'Повар': 11500.0},
#  {'Плотник-бетонщик (в РФ)': 1165.0},
#  {'Педагог классического танца\\Педагог развития данных': 1250.0},
#  {'Парикмахер-универсал': 75000.0},
#  {'Парикмахер': 80000.0},
#  {'Оформитель документов': 40000},
#  {'Официант-бармен': 450},
#  {'Официант в коктейльный бар': 50000.0},
#  {'Официант': 40000},
#  {'Офис-менеджер': 43750.0},
#  {'Организатор фестиваля': 50000.0},
#  {'Облицовщик-плиточник (в РФ)': 1500.0},
#  {'Няня': 21000.0},
#  {'Начинающий специалист': 25000.0},
#  {'Начальника отдела кадров': 150000},
#  {'Монтажник сантехсистем и оборудования (сантехник) в РФ': 70000.0},
#  {'Монтажник оборудования связи': 400},
#  {'Монтажник лифтов': 82500.0},
#  {'Монтажник СКС': 50000},
#  {'Методолог Корпоративные Кредиты': 225000.0},
#  {'Менеджер торгового сектора/Спорт-лидер (спортивные товары, м. Юго-Западная)': 75000.0},
#  {'Менеджер торгового зала / Спорт-лидер (спортивные товары, м. Фили)': 80000.0},
#  {'Менеджер торгового зала / Спорт-лидер (спортивные товары, м. Пражская)': 80000.0},
#  {'Менеджер ресторана': 55000},
#  {'Менеджер проектов': 62500.0},
#  {'Менеджер по туризму': 27500.0},
#  {'Менеджер по товару в ТЦ "Cubus", Гатчина': 30000},
#  {'Менеджер по товару в ТК Меркурий': 30000},
#  {'Менеджер по товару в ТК "Ярмарка"': 26000},
#  {'Менеджер по товару / Кладовщик (ТЦ "Сити")': 26000},
#  {'Менеджер по товару / Кладовщик': 27000},
#  {'Менеджер по сопровождению программного обеспечения ОМС': 55000.0},
#  {'Менеджер по рекламе и маркетингу': 30000},
#  {'Менеджер по работе с корпоративными клиентами': 57500.0},
#  {'Менеджер по работе с клиентами (образование за рубежом)': 60000},
#  {'Менеджер по работе с клиентами': 22500.0},
#  {'Менеджер по работе с дистрибьюторами и аптечными сетями': 220000},
#  {'Менеджер по продаже услуг': 35000},
#  {'Менеджер по продажам услуг': 32500.0},
#  {'Менеджер по продажам туристических услуг': 20000},
#  {'Менеджер по продажам технической продукции': 35000},
#  {'Менеджер по продажам строительных материалов': 60000},
#  {'Менеджер по продажам сервиса онлайн-записи': 67500.0},
#  {'Менеджер по продажам септиков': 30000},
#  {'Менеджер по продажам профессиональной косметики для волос': 105000.0},
#  {'Менеджер по продажам оптового отдела': 90000.0},
#  {'Менеджер по продажам мебели': 30000},
#  {'Менеджер по продажам и обслуживанию / Продавец-консультант в салон "Ростелеком" (м. Чкаловская)': 40000.0},
#  {'Менеджер по продажам в отель': 37500.0},
#  {'Менеджер по продажам': 150000},
#  {'Менеджер по подбору персонала': 50000},
#  {'Менеджер по персоналу': 36250.0},
#  {'Менеджер по оптовым продажам': 44250.0},
#  {'Менеджер по маркетингу и PR': 40000},
#  {'Менеджер по кредитованию': 48000.0},
#  {'Менеджер отдела продаж': 61250.0},
#  {'Менеджер отдела закупок': 75000.0},
#  {'Менеджер оптового отдела продаж': 57500.0},
#  {'Менеджер интернет-магазина (Одежда, текстильная продукция)': 27500.0},
#  {'Менеджер / Менеджер по работе с клиентами': 39000},
#  {'Медицинская сестра палатная': 25000},
#  {'Медицинская сестра': 40000},
#  {'Машинист катка дорожного/асфальтового': 65000.0},
#  {'Мастер по сварке': 100000.0},
#  {'Мастер по наращиванию ресниц': 40000},
#  {'Мастер отделочных работ / Отделочник': 32.5},
#  {'Мастер ногтевого сервиса': 32500.0},
#  {'Маляр по дереву': 40000.0},
#  {'Личный помощник руководителя / Персональный ассистент': 287649},
#  {'Личный помощник руководителя': 33850.0},
#  {'Лаборант по отбору проб пыли и газов': 20000.0},
#  {'Кредитный специалист (м.Проспект Большевиков)': 30000},
#  {'Кредитный специалист (м. Садовая)': 23000},
#  {'Кредитный специалист (м. Речной вокзал)': 26500.0},
#  {'Кредитный специалист (м. Проспект Просвещения)': 30000},
#  {'Кредитный специалист (ЧМЗ)': 15000},
#  {'Кредитный специалист': 22500.0},
#  {'Кредитный консультант': 28000},
#  {'Креативный дизайнер': 100000.0},
#  {'Косметолог-эстетист': 45000.0},
#  {'Контент менеджер (Маркетинг) / Специалист по рекламе': 40000},
#  {'Консультант (помощник) нотариуса': 40000.0},
#  {'Клубный промоутер': 50000.0},
#  {'Кладовщик': 21475.0},
#  {'Кассир-операционист': 27000.0},
#  {'Кассир, г. Егорьевск': 32500.0},
#  {'Каменщик (в РФ)': 70000.0},
#  {'Инженер/инженер отдела инженерных изысканий (2 категория)': 25000},
#  {'Инженер-электронщик': 52500.0},
#  {'Инженер-сметчик': 50000},
#  {'Инженер-проектировщик': 32500.0},
#  {'Инженер-программист микроконтроллеров / Embedded engineer': 95000.0},
#  {'Инженер по эксплуатации теплотехнического оборудования': 70000},
#  {'Инженер по охране труда': 50000},
#  {'Инженер по внедрению информационных систем': 55000.0},
#  {'Инженер отдела организации и планирования ПИР': 26000},
#  {'Инженер ПТО по сварочно-монтажным работам': 70000},
#  {'Инженер ПТО (дорожное строительство)': 70000},
#  {'Инженер (1 категория)': 25000},
#  {'Заместитель руководителя по работе с регионами': 35000},
#  {'Заместитель директора магазина (Спб)': 40000},
#  {'Директор фитнес-клуба': 100000},
#  {'Директор филиала': 160000},
#  {'Директор по развитию ипотечного кредитования': 165000.0},
#  {'Директор по продажам IT проектов.': 150000},
#  {'Дизайнер-консультант по шторам, обоям': 50000},
#  {'Дизайнер-консультант / Менеджер по продажам без опыта (кухонная мебель, ТЦ Красный Кит)': 60000},
#  {'Делопроизводитель / Офис Менеджер в офис (интернет-магазин)': 30000},
#  {'Грузчик-комплектовщик': 21500.0},
#  {'Грузчик': 23500.0},
#  {'Главный/ведущий специалист/заместитель Руководителя Управление внутреннего аудита': 87000.0},
#  {'Главный технолог/ разработчик ЛКМ': 100000},
#  {'Главный менеджер по развитию ипотечного кредитования': 30700},
#  {'Главный инженер проекта/ ГИП': 100000.0},
#  {'Главный бухгалтер': 175000.0},
#  {'Гипсокартонщик / Плотник-отделочник в РФ': 80000.0},
#  {'Врач-хирург (Екатеринбург)': 37500.0},
#  {'Врач-уролог': 34250.0},
#  {'Врач-терапевт участковый (Поликлиника, ул.Удельная)': 75000.0},
#  {'Врач-терапевт / семейный врач': 57500.0},
#  {'Врач-терапевт (терапевтическое отделение стационара), Екатеринбург': 32000},
#  {'Врач-статистик': 35000},
#  {'Врач-рентгенолог МРТ и КТ': 70000.0},
#  {'Врач-рентгенолог': 35000},
#  {'Врач-оторин\u2062оларинголог (Екатеринбург)': 36500},
#  {'Врач-кардиолог (Екатеринбург)': 34500.0},
#  {'Врач-кардиолог': 34500.0},
#  {'Врач функциональной диагностики': 35000},
#  {'Врач травматолог-ортопед (травмпункт, Екатеринбург)': 49500.0},
#  {'Врач травматолог-ортопед (Екатеринбург)': 49500.0},
#  {'Врач травматолог-ортопед': 35000},
#  {'Врач стоматолог-терапевт': 60000.0},
#  {'Врач по паллиативной медицинской помощи выездной службы (Екатеринбург)': 37500.0},
#  {'Водитель-экспедитор с личным грузовым автомобилем от 1,5 до 2 тонн': 47500.0},
#  {'Водитель-экспедитор с личным грузовым автомобилем (от 1,5 до 2 тонн, будка)': 41500.0},
#  {'Водитель-экспедитор с личным грузовым автомобилем': 85000.0},
#  {'Водитель-экспедитор': 1200},
#  {'Водитель-курьер': 13500.0},
#  {'Водитель такси на личном автомобиле': 1500.0},
#  {'Водитель такси': 60000},
#  {'Водитель с личным грузовым автомобилем (Рефрижератор, Изотерм, Фургон, Тент)': 75000.0},
#  {'Водитель на автомобиль компании Hyundai Solaris Nissan Almera': 110000.0},
#  {'Водитель на авто компании, Киев': 14000.0},
#  {'Водитель дорожной техники с кат.В для работы в РФ': 64000.0},
#  {'Водитель дорожной техники (категории С, D, Е) на машину КАМАЗ/КАМАЗ с прицепом в РФ': 64000.0},
#  {'Водитель МАЗ бункеровоз': 45000},
#  {'Водитель Uber на авто компании': 1025.0},
#  {'Вечерний секретарь': 50000.0},
#  {'Вечерний Консультант 1С': 15000.0},
#  {'Ведущий специалист центрального офиса продаж': 150000},
#  {'Ведущий специалист по контекстной рекламе': 100000},
#  {'Ведущий разработчик Java': 170000.0},
#  {'Ведущий менеджер по туризму CORAL TRAVEL': 130000.0},
#  {'Ведущий менеджер по продажам': 60000.0},
#  {'Ведущий инженер/главный инженер': 110000.0},
#  {'Ведущий инженер по слаботочным системам и автоматике': 60000},
#  {'Ведущий инженер по качеству (Senior Manual QA Engineer)': 110000.0},
#  {'Ведущий инженер отдела экологической и промышленной безопасности': 25000},
#  {'Ведущий инженер отдела мониторинга разработки': 40000},
#  {'Ведущий инженер отдела геологии и подсчета запасов': 35000},
#  {'Ведущий инженер': 25000},
#  {'Ведущий PHP/JS разработчик': 130000.0},
#  {'Веб-программист': 45000},
#  {'Веб-дизайнер': 100000},
#  {'Бухгалтер 1 категории': 25000},
#  {'Бухгалтер': 47500.0},
#  {'Брокер по коммерческой недвижимости': 140000.0},
#  {'Бровист': 50000},
#  {'Бармен/Бариста': 400},
#  {'Бармен-официант': 35000.0},
#  {'Бармен-кассир': 38000},
#  {'Бармен-кальянщик': 37500.0},
#  {'Бармен,официант,повар,администратор,кальянщик,кухонный рабочий': 400.0},
#  {'Бармен': 38750.0},
#  {'Бариста': 12812.5},
#  {'Ассистент аккаунт-менеджера': 32500.0},
#  {'Арматурщик (Российская Федерация)': 70000.0},
#  {'Акушерка/Акушер': 25000},
#  {'Администратор-оператор': 30000},
#  {'Администратор-кассир стоматологической клиники': 45000},
#  {'Администратор фитнес студии': 30000.0},
#  {'Администратор стоматологической клиники': 25000},
#  {'Администратор салона красоты': 8850.0},
#  {'Администратор региона': 22000.0},
#  {'Администратор отеля': 40000.0},
#  {'Администратор в сауну': 62500.0},
#  {'Администратор СПА-салона': 50000.0},
#  {'Администратор': 13500.0},
#  {'Административный помощник': 35000},
#  {'Агент по продажам жилой недвижимости': 70000},
#  {'Автоэлектрик': 60000},
#  {'Автослесарь': 15675.0},
#  {'Автомеханик': 45000.0},
#  {'Інспектор прикордонної служби': 7250},
#  {'Web-дизайнер': 70000.0},
#  {'Web разработчик (python) / руководитель группы': 100000.0},
#  {'Senior Backend (Node.JS) Developer': 100000},
#  {'SMM-менеджер(банк)': 80000.0},
#  {'SMM-менеджер': 50000},
#  {'SMM-маркетинг менеджер': 70000},
#  {'SEO-специалист': 32500.0},
#  {'Ruby on Rails backend разработчик': 115000},
#  {'Quality Assurance Engineer': 1050.0},
#  {'Python разработчик': 100000.0},
#  {'Product Designer/Дизайнер продукта': 80000},
#  {'PHP Developer': 1500.0},
#  {'Middle Front-end developer/верстальщик': 1500.0},
#  {'Lead Developer': 3300.0},
#  {'Junior Documentation Manager': 17500.0},
#  {'IT and Digital Programs Coordinator': 78000},
#  {'HTML-верстальщик': 90000},
#  {'HR Менеджер по подбору персонала': 45000.0},
#  {'Full-stack разработчик (PHP)': 80000},
#  {'Frontend-разработчик / HTML-верстальщик': 80000},
#  {'Frontend Developer': 135000.0},
#  {'Export Documentation Manager': 24000.0},
#  {'Dispatch manager / Менеджер по логистике': 650.0},
#  {'Cистемный администратор (Руководитель группы администраторов)': 75000.0},
#  {'Backend/PHP разработчик Middle': 70000},
#  {'Account manager (Sport marketing)': 80000},
#  {'Account Manager/Аккаунт Менеджер': 140000.0}]

# %%
masss=[]
for i in med:
    for j in i.values():
        masss.append(j)
masss
# Out:
# [35000.0,
#  90000,
#  30000.0,
#  70000,
#  60000,
#  185000.0,
#  30000,
#  30000,
#  105000.0,
#  40000.0,
#  20000,
#  18500.0,
#  40000.0,
#  60000,
#  3300.0,
#  30000,
#  100000,
#  35000,
#  25000,
#  80000.0,
#  70000.0,
#  40000,
#  40000,
#  30000.0,
#  50000.0,
#  20000,
#  35000,
#  55000.0,
#  25000,
#  85000.0,
#  32500.0,
#  27500.0,
#  22000,
#  29500.0,
#  19000,
#  20000,
#  50000.0,
#  1850.0,
#  48000,
#  10000,
#  70000,
#  35000.0,
#  25000,
#  40000,
#  20500.0,
#  80000,
#  115000.0,
#  42500.0,
#  50000.0,
#  65000.0,
#  30000,
#  37500.0,
#  45000.0,
#  30000,
#  33000.0,
#  52000,
#  20000,
#  52000,
#  600,
#  25000,
#  65000.0,
#  35000.0,
#  120000,
#  25000,
#  45000,
#  125000.0,
#  40000,
#  600000.0,
#  16000.0,
#  30000.0,
#  30000,
#  192500.0,
#  70000.0,
#  65000,
#  30000,
#  60000,
#  40000.0,
#  115000.0,
#  85000.0,
#  15000.0,
#  115000,
#  110000.0,
#  42500.0,
#  35000.0,
#  45000,
#  30000,
#  37500.0,
#  100000,
#  40000.0,
#  80000,
#  87500.0,
#  21500.0,
#  30000.0,
#  24000.0,
#  20000.0,
#  60000,
#  40000.0,
#  32000.0,
#  61000.0,
#  60000.0,
#  90000,
#  40000,
#  35000,
#  46000.0,
#  30000.0,
#  90000.0,
#  10000,
#  30000.0,
#  70000,
#  35000,
#  20000,
#  50000.0,
#  65000,
#  70000,
#  21693,
#  34500.0,
#  80000.0,
#  125000.0,
#  40000,
#  70000.0,
#  38000,
#  700,
#  40000.0,
#  82500.0,
#  82500.0,
#  90000.0,
#  100000,
#  45000.0,
#  80000,
#  15000,
#  800,
#  14000.0,
#  20000,
#  20000,
#  30000.0,
#  60000,
#  70000,
#  25500.0,
#  80000.0,
#  65000.0,
#  110000.0,
#  80000,
#  25000,
#  55000.0,
#  50000,
#  25000,
#  130000.0,
#  22500.0,
#  33000.0,
#  32500.0,
#  21825.0,
#  21825.0,
#  30000.0,
#  27000,
#  1300,
#  33500.0,
#  80000.0,
#  18000,
#  130000,
#  109000.0,
#  25000.0,
#  45000.0,
#  137500.0,
#  36000,
#  30900.0,
#  55000.0,
#  23000.0,
#  27325.0,
#  700.0,
#  65000.0,
#  26500.0,
#  35000,
#  21600.0,
#  35000,
#  40000,
#  20000.0,
#  24000.0,
#  22450.0,
#  62500.0,
#  30000,
#  750.0,
#  65000.0,
#  27050.0,
#  19400.0,
#  1500.0,
#  35000.0,
#  40000.0,
#  40000.0,
#  23600.0,
#  35000,
#  33600,
#  25750.0,
#  70000.0,
#  25000,
#  80000.0,
#  23050.0,
#  90000.0,
#  45000.0,
#  90000.0,
#  60000.0,
#  22500.0,
#  35000.0,
#  28700.0,
#  105000.0,
#  30000,
#  20000,
#  19000.0,
#  55000,
#  55000,
#  81250.0,
#  50000,
#  40000.0,
#  600,
#  30000.0,
#  37500.0,
#  70000,
#  120000,
#  55000,
#  40000.0,
#  55000,
#  55000,
#  70000,
#  55000,
#  55000,
#  55000,
#  10000.0,
#  55000,
#  80000,
#  55000,
#  55000,
#  22500.0,
#  15000,
#  21250.0,
#  40000,
#  115000.0,
#  42250.0,
#  40000,
#  30000,
#  55000,
#  37500.0,
#  55000,
#  42250.0,
#  30000,
#  1200,
#  55000,
#  45000,
#  50000,
#  45000,
#  55000,
#  5000,
#  55000,
#  50000.0,
#  55000,
#  105000.0,
#  80000.0,
#  55000,
#  33000.0,
#  37500.0,
#  65000.0,
#  20000,
#  33000.0,
#  47500.0,
#  8000,
#  28000,
#  55000,
#  26550.0,
#  55000,
#  40000,
#  25500.0,
#  45000,
#  55000,
#  55000,
#  180000.0,
#  32500.0,
#  25000,
#  25000,
#  37000,
#  40000,
#  50000,
#  55000.0,
#  25000.0,
#  30000,
#  30000,
#  40000,
#  25000.0,
#  30000.0,
#  47500.0,
#  12500.0,
#  800,
#  600,
#  45000.0,
#  32500.0,
#  30000,
#  27500.0,
#  47500.0,
#  27500.0,
#  50000.0,
#  47500.0,
#  30000,
#  30000,
#  30000,
#  30000,
#  30000,
#  75000.0,
#  30000,
#  30000,
#  30000,
#  27000,
#  25500.0,
#  180000,
#  23000.0,
#  25500.0,
#  50000.0,
#  30000,
#  50000,
#  55000,
#  60000,
#  30000,
#  60000.0,
#  80000,
#  15500.0,
#  400.0,
#  35000.0,
#  55000.0,
#  35000.0,
#  35000,
#  72500.0,
#  117500.0,
#  100000,
#  100000,
#  32500.0,
#  57500.0,
#  70000.0,
#  26500.0,
#  57500.0,
#  40000.0,
#  29300.0,
#  24000,
#  20000,
#  45000.0,
#  70000,
#  40000.0,
#  15000,
#  687.5,
#  35000,
#  26500.0,
#  50000.0,
#  30000,
#  35000,
#  60000,
#  30000.0,
#  40000,
#  50000.0,
#  80000,
#  65.0,
#  32500.0,
#  40000.0,
#  65000.0,
#  57500.0,
#  65000.0,
#  32500.0,
#  24000,
#  47500.0,
#  700.0,
#  15000,
#  20000.0,
#  65.0,
#  87500.0,
#  35000.0,
#  70000.0,
#  60000.0,
#  35000,
#  68500.0,
#  25000,
#  122500.0,
#  100000,
#  700.0,
#  1000000,
#  70000.0,
#  40000.0,
#  85000.0,
#  27000,
#  32000.0,
#  20000,
#  50000.0,
#  45000,
#  36000,
#  27500.0,
#  125000.0,
#  70000,
#  130000.0,
#  35000,
#  45000.0,
#  40000,
#  55000.0,
#  150000,
#  15500.0,
#  65000.0,
#  9750.0,
#  15000,
#  45000,
#  75000.0,
#  17500.0,
#  25000.0,
#  37500.0,
#  35000.0,
#  30000,
#  27000,
#  30000,
#  26000,
#  30000,
#  24000,
#  22000,
#  30000,
#  30000,
#  32500.0,
#  27500.0,
#  70000,
#  70000.0,
#  22000.0,
#  13500.0,
#  65000,
#  9000.0,
#  40000,
#  27000.0,
#  13500.0,
#  56000.0,
#  30000.0,
#  45000,
#  30000.0,
#  40000,
#  45000.0,
#  11500.0,
#  1165.0,
#  1250.0,
#  75000.0,
#  80000.0,
#  40000,
#  450,
#  50000.0,
#  40000,
#  43750.0,
#  50000.0,
#  1500.0,
#  21000.0,
#  25000.0,
#  150000,
#  70000.0,
#  400,
#  82500.0,
#  50000,
#  225000.0,
#  75000.0,
#  80000.0,
#  80000.0,
#  55000,
#  62500.0,
#  27500.0,
#  30000,
#  30000,
#  26000,
#  26000,
#  27000,
#  55000.0,
#  30000,
#  57500.0,
#  60000,
#  22500.0,
#  220000,
#  35000,
#  32500.0,
#  20000,
#  35000,
#  60000,
#  67500.0,
#  30000,
#  105000.0,
#  90000.0,
#  30000,
#  40000.0,
#  37500.0,
#  150000,
#  50000,
#  36250.0,
#  44250.0,
#  40000,
#  48000.0,
#  61250.0,
#  75000.0,
#  57500.0,
#  27500.0,
#  39000,
#  25000,
#  40000,
#  65000.0,
#  100000.0,
#  40000,
#  32.5,
#  32500.0,
#  40000.0,
#  287649,
#  33850.0,
#  20000.0,
#  30000,
#  23000,
#  26500.0,
#  30000,
#  15000,
#  22500.0,
#  28000,
#  100000.0,
#  45000.0,
#  40000,
#  40000.0,
#  50000.0,
#  21475.0,
#  27000.0,
#  32500.0,
#  70000.0,
#  25000,
#  52500.0,
#  50000,
#  32500.0,
#  95000.0,
#  70000,
#  50000,
#  55000.0,
#  26000,
#  70000,
#  70000,
#  25000,
#  35000,
#  40000,
#  100000,
#  160000,
#  165000.0,
#  150000,
#  50000,
#  60000,
#  30000,
#  21500.0,
#  23500.0,
#  87000.0,
#  100000,
#  30700,
#  100000.0,
#  175000.0,
#  80000.0,
#  37500.0,
#  34250.0,
#  75000.0,
#  57500.0,
#  32000,
#  35000,
#  70000.0,
#  35000,
#  36500,
#  34500.0,
#  34500.0,
#  35000,
#  49500.0,
#  49500.0,
#  35000,
#  60000.0,
#  37500.0,
#  47500.0,
#  41500.0,
#  85000.0,
#  1200,
#  13500.0,
#  1500.0,
#  60000,
#  75000.0,
#  110000.0,
#  14000.0,
#  64000.0,
#  64000.0,
#  45000,
#  1025.0,
#  50000.0,
#  15000.0,
#  150000,
#  100000,
#  170000.0,
#  130000.0,
#  60000.0,
#  110000.0,
#  60000,
#  110000.0,
#  25000,
#  40000,
#  35000,
#  25000,
#  130000.0,
#  45000,
#  100000,
#  25000,
#  47500.0,
#  140000.0,
#  50000,
#  400,
#  35000.0,
#  38000,
#  37500.0,
#  400.0,
#  38750.0,
#  12812.5,
#  32500.0,
#  70000.0,
#  25000,
#  30000,
#  45000,
#  30000.0,
#  25000,
#  8850.0,
#  22000.0,
#  40000.0,
#  62500.0,
#  50000.0,
#  13500.0,
#  35000,
#  70000,
#  60000,
#  15675.0,
#  45000.0,
#  7250,
#  70000.0,
#  100000.0,
#  100000,
#  80000.0,
#  50000,
#  70000,
#  32500.0,
#  115000,
#  1050.0,
#  100000.0,
#  80000,
#  1500.0,
#  1500.0,
#  3300.0,
#  17500.0,
#  78000,
#  90000,
#  45000.0,
#  80000,
#  80000,
#  135000.0,
#  24000.0,
#  650.0,
#  75000.0,
#  70000,
#  80000,
#  140000.0]

# %%
matplotlib.pyplot.hist(masss)
# Out:
# (array([604.,  44.,   3.,   0.,   0.,   1.,   0.,   0.,   0.,   1.]),
#  array([3.2500000e+01, 1.0002925e+05, 2.0002600e+05, 3.0002275e+05,
#         4.0001950e+05, 5.0001625e+05, 6.0001300e+05, 7.0000975e+05,
#         8.0000650e+05, 9.0000325e+05, 1.0000000e+06]),
#  <a list of 10 Patch objects>)
